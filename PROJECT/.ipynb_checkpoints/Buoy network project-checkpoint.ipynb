# %% [markdown]
# ## Description of the problem
#
# The problem concerns a network of buoys that produce electricity from renewable sources and use this energy for water desalination. Furthermore, vessels (such as boats) can go to a buoy to stock up on desalinated water and energy. The goal is to efficiently manage the production and use of resources.
#
# ## Detail of the Model
# ### Production and Desalination System
#
# Each buoy is equipped with:
# * Energy production system: produces electricity from renewable sources, indicated as $c_r$
# * Battery: stores the energy produced with a discharge efficiency $r_s$
# * Desalination system: Transforms energy into desalinated water with an efficiency $r_d$.
#
# ## Dynamic Equations
#
# The dynamic equations describe the evolution of the accumulated energy and desalinated water over time.

# %% [markdown]
# ### First case for each boy
# $$
#     \begin{cases}
#       x_1(k+1)=c_r\\
#       x_2(k+1)=x_2(k)+\frac{x_1(k)}{k_c}
#     \end{cases}\
# $$
#
# $$
#     x(k+1)=
#     \begin{bmatrix}
#     0 & 0 \\
#     \frac{1}{k_c} & 1
#     \end{bmatrix}
#     \begin{bmatrix}
#     x_1 \\
#     x_2
#     \end{bmatrix}
#     +
#     \begin{bmatrix}
#     c_r \\
#     0
#     \end{bmatrix}
# $$
#
# Where:
# * $x_1$ represents the accumulated energy.
# * $x_2$ represents accumulated water.
# * $c_r$ is the constant amount of renewable energy available.
# * $k_c$ is an energy to water conversion parameter.

# %% [markdown]
# ## Second case for each boy
# $$
#     \begin{cases}
#       x_1(k+1)=x_1(k)-k_cx_2(k)+(c_r+k_cx_2^t)\\
#       x_2(k+1)=x_2^t
#     \end{cases}\
# $$
#
# $$
#     x(k+1)=
#     \begin{bmatrix}
#     1 & -k_c \\
#     0 & 0
#     \end{bmatrix}
#     x(k)
#     +
#     \begin{bmatrix}
#     c_r+k_cx_2^t \\
#     x_2^t
#     \end{bmatrix}
# $$

# %% [markdown]
# ## Complete case
# $$
# \begin{bmatrix}
# \begin{bmatrix}
# x_1^1 \\
# x_2^1
# \end{bmatrix} \\
# .\\.\\.\\.\\
# \begin{bmatrix}
# x_1^n \\
# x_2^n
# \end{bmatrix}
# \end{bmatrix}
# =
# \begin{bmatrix}
# \begin{bmatrix}
# [A_{sc}^1 \text{ or } A_{si}^1] & . \\
# . & [A_{sc}^2 \text{ or } A_{si}^2] & . \\
# . & . & . \\
# . & . & . \\
# . & . & . \\
# . & . & . \\
# . & . & . \\
# \end{bmatrix}
# \end{bmatrix}
# \begin{bmatrix}
# \begin{bmatrix}
# x_1^1(k) \\
# x_2^1(k)
# \end{bmatrix} \\
# .\\.\\.\\.\\.
# \begin{bmatrix}
# x_1^n(k) \\
# x_2^n(k)
# \end{bmatrix}
# \end{bmatrix}
# +
# \begin{bmatrix}
# \begin{bmatrix}
# 1 & 0 \\
# 0 & 1
# \end{bmatrix} \\
# \begin{bmatrix}
# 0 & 0 \\
# 0 & 0
# \end{bmatrix} \\
# .\\.\\.\\.
# \end{bmatrix}
# \begin{bmatrix}
# u_1 \\
# u_2
# \end{bmatrix}
# $$
#
# * $A_{sc}$: Represents complete discharge, i.e. the situation in which all available energy is used or withdrawn.
# * $A_{si}$: Represents incomplete discharge, i.e. the situation in which only a part of the available energy is used or withdrawn.
#
# ### Ratio between Complete and Incomplete Discharge_QUESTA PARTE CI POSSIAMO PENSARE, MA DERIVA DA UN MIO ERRORE DI SCRITTURA
# The ratio $\frac{A_{sc}^1}{A_{si}^1}$ for the 1st mark can be interpreted as a measure of efficiency or the effectiveness with which energy and water are used compared to ideal conditions (full discharge).
#
# ### Interpretation of the Report
#
# 1. System Efficiency:
#     * A larger value of the $$\frac{A_{sc}^1}{A_{si}^1}$$ ratio indicates that the buoy is more efficient at using available energy than an incomplete discharge.
#     * A lower value may indicate inefficiencies or losses in the system.
#
# 2. Resource Management:
#     * The ratio helps determine how well resources are being used compared to an ideal situation.
#     * It can be used to optimize resource management, balancing between complete and incomplete discharges as needed.
#
# ### Practical Example
#
# Suppose that:
#
# * $A_{sc}^1$ is a matrix or factor representing the amount of energy completely discharged by the first buoy.
# * $A_{si}^1$ represents the amount of energy incompletely discharged.
#
# If $A_{sc}^1$=100 energy units and $A_{si}^1$=50 energy units, the ratio would be $\frac{100}{50}$=2. This ratio can be used to evaluate the buoy's performance relative to ideal energy use.
#
# The $\frac{A_{sc}^1}{A_{si}^1}$ ratio indicates the relative efficiency of complete discharge versus incomplete discharge for the 1st buoy. This concept is crucial to optimize resource management in the buoy network, allowing real behavior to be compared with ideal behavior and improving operational strategies.

# %% [markdown]
# ### Hypothesis:
# * Do priorità alla produzione di acqua
# * voglio arrivare ad $x_1^{target}$ ed $x_2^{target}$
#
# ## Case 1
# La batteria non permette di ricaricare tutto il tank
#
# $$
# \frac{x_1}{k_c}<(x_2^t-x_2))
# $$
#
# where the first term of the inequality indicates the maximum reproducible quantity of water and the second the quantity of water required to reach the target.
#
# $$
#     \begin{cases}
#       x_1(k+1)=x_1(k)+c_r-\frac{k_cx_1(k)}{k_c}\\
#       x_2(k+1)=x_2(k)+\frac{x_1(k)}{k_c}
#     \end{cases}\
# $$
#
# the result is:
#
# $$
#     \begin{cases}
#       x_1=c_r\\
#       x_2<x_2^t
#     \end{cases}\
# $$

# %% [markdown]
# ## Case 2
# I charge the entire tank thanks to the battery
#
# $$
# \frac{x_1}{k_c}>(x_2^t-x_2))
# $$
#
# $$
#     \begin{cases}
#       x_1(k+1)=x_1(k)+c_r-k_c(x_2^t-x_2(k))\\
#       x_2(k+1)=x_2(k)+(x_2^t-x_2(k))
#     \end{cases}\
# $$
#
# the result is:
#
# $$
#     \begin{cases}
#       x_1\ne0\\
#       x_2=x_2^t
#     \end{cases}\
# $$

# %% [markdown]
# ## Energy flow
# ![SNOWFALL](./images/energetic-flow.png)
#
# The energy flow diagram shows the transformation of renewable energy into water through the battery and desalination process:
#
# 1. Renewable energy $c_r$.
# 2. Battery with discharge efficiency $r_s$.
# 3. Desalination with efficiency $r_d$.
# 4. Water accumulation in the tank.
#
# Where the conversion is given by:
# $$
# \frac{1}{k_c}
# $$

# %% [markdown]
# ### Considerations for Vessels
#
# Vessels that go to the buoys to stock up on water and energy must be integrated into the model. You can think of adding variables that represent the quantity of resources taken from the boats:
# * $u_1$: Energy withdrawn.
# * $u_2$: Water taken.
#
# The full model could then include these withdrawals in the dynamic equations:
# $$
# \begin{cases}
# x_1(k + 1) = c_r - u_1 \\
# x_2(k + 1) = x_2(k) + \frac{x_1(k)}{k_s} - u_2
# \end{cases}
# $$

# %% [markdown]
# # VERSIONE CON ASSEGNAZIONE A PRIMA BOA CON RISORSE DISPONIBILI

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametri globali
n = 3  # numero di boe
cr = 4.6  # produzione costante di energia rinnovabile per timestep
kc = 0.05  # parametro di conversione energia-acqua
timesteps = 50  # durata della simulazione
initial_energy = 0  # livello iniziale di energia
initial_water = 0  # livello iniziale di acqua
max_energy = 5  # energia massima accumulabile
min_energy = 0.2 * max_energy  # 20% del totale dell'energia accumulabile
max_water = 10  # acqua massima accumulabile
x2_target = 10  # livello target dell'acqua (usato nelle condizioni)
max_vessels = 2  # numero massimo di natanti che possono arrivare in ciascun timestep

# Funzione per inizializzare i vettori di stato
def initialize_state_vectors(n, timesteps, initial_energy, initial_water):
    x1 = np.zeros((n, timesteps + 1))  # energia accumulata per ciascuna boa
    x2 = np.zeros((n, timesteps + 1))  # acqua accumulata per ciascuna boa
    x1[:, 0] = initial_energy
    x2[:, 0] = initial_water
    return x1, x2

# Funzione per generare richieste randomiche
def generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water):
    u1 = np.zeros((max_vessels, timesteps + 1))  # energia richiesta da ciascun natante
    u2 = np.zeros((max_vessels, timesteps + 1))  # acqua richiesta da ciascun natante
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        num_vessels = np.random.randint(0, max_vessels)  # numero di natanti al timestep k
        for i in range(num_vessels):
            max_possible_energy_request = max_energy - min_energy
            u1[i, k] = np.random.uniform(0, max_possible_energy_request)
            u2[i, k] = np.random.uniform(0, max_water)
    return u1, u2

# Funzione per aggiornare lo stato delle boe
def update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water):
    for i in range(n):
        if x1[i, k] / kc < (x2_target - x2[i, k]):
            # Caso 1: La batteria non ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr
            x2[i, k + 1] = x2[i, k] + (x1[i, k] / kc)
        else:
            # Caso 2: La batteria ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr - kc * (x2_target - x2[i, k])
            x2[i, k + 1] = x2_target

        # Assicura che l'energia non superi il massimo
        if x1[i, k + 1] > max_energy:
            x1[i, k + 1] = max_energy

        # Assicura che l'acqua non superi il limite massimo
        if x2[i, k + 1] > max_water:
            x2[i, k + 1] = max_water
    return x1, x2

# Funzione per assegnare le richieste dei natanti alle boe
def assign_requests(x1, x2, u1, u2, k, num_vessels, min_energy, max_energy, max_water):
    for i in range(num_vessels):
        assigned = False
        for j in range(n):
            if (x1[j, k + 1] - u1[i, k] >= min_energy and x1[j, k + 1] - u1[i, k] <= max_energy and
                x2[j, k + 1] - u2[i, k] >= 0 and x2[j, k + 1] - u2[i, k] <= max_water):
                # Assegna la richiesta alla boa j
                x1[j, k + 1] -= u1[i, k]
                x2[j, k + 1] -= u2[i, k]

                # Assicura che l'energia non scenda sotto la soglia minima
                if x1[j, k + 1] < min_energy:
                    x1[j, k + 1] = min_energy

                # Assicura che l'acqua non scenda sotto 0
                if x2[j, k + 1] < 0:
                    x2[j, k + 1] = 0

                # Stampa le richieste e le risorse aggiornate per la boa assegnata
                print(f"Vessel {i + 1} assigned to Buoy {j + 1}:")
                print(f"  Energy requested: {u1[i, k]}")
                print(f"  Water requested: {u2[i, k]}")
                print(f"  Updated energy for Buoy {j + 1}: {x1[j, k + 1]}")
                print(f"  Updated water for Buoy {j + 1}: {x2[j, k + 1]}")
                assigned = True
                break
        
        if not assigned:
            print(f"Vessel {i + 1} could not be assigned at time step {k + 1}")

# Funzione per eseguire la simulazione
def run_simulation(n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels):
    x1, x2 = initialize_state_vectors(n, timesteps, initial_energy, initial_water)
    u1, u2 = generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water)

    for k in range(timesteps):
        print(f"Time step {k + 1}")
        num_vessels = np.random.randint(1, max_vessels + 1)  # numero di natanti al timestep k
        x1, x2 = update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water)
        assign_requests(x1, x2, u1, u2, k, num_vessels, min_energy, max_energy, max_water)
        print("\n")

    return x1, x2

# Funzione per visualizzare i risultati
def plot_results(x1, x2, n, timesteps, min_energy, max_energy, max_water):
    plt.figure(figsize=(12, 6))

    for i in range(n):
        plt.subplot(n, 2, 2 * i + 1)
        plt.plot(x1[i], label=f'Accumulated Energy Buoy {i+1}')
        plt.axhline(min_energy, color='r', linestyle='--', label='Min Energy Threshold')
        plt.axhline(max_energy, color='g', linestyle='--', label='Max Energy Threshold')
        plt.xlabel('Time step')
        plt.ylabel('Energy')
        plt.legend()
        plt.grid(True)

        plt.subplot(n, 2, 2 * i + 2)
        plt.plot(x2[i], label=f'Accumulated Water Buoy {i+1}')
        plt.axhline(max_water, color='b', linestyle='--', label='Max Water Threshold')
        plt.xlabel('Time step')
        plt.ylabel('Water')
        plt.legend()
        plt.grid(True)

    plt.tight_layout()
    plt.show()

# Esegui la simulazione
x1, x2 = run_simulation(n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels)

# Visualizza i risultati
plot_results(x1, x2, n, timesteps, min_energy, max_energy, max_water)
# Out:
# Time step 1
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 4.6
#   Updated water for Buoy 1: 0.0
#
#
# Time step 2
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 3.8028572256396647
#   Water requested: 7.319939418114051
#   Updated energy for Buoy 1: 1.1971427743603353
#   Updated water for Buoy 1: 2.6800605818859493
#
#
# Time step 3
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
# Vessel 2 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 4
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 5
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
# Vessel 2 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 6
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.6239780813448106
#   Water requested: 0.5808361216819946
#   Updated energy for Buoy 1: 4.376021918655189
#   Updated water for Buoy 1: 9.419163878318006
# Vessel 2 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 4.376021918655189
#   Updated water for Buoy 1: 9.419163878318006
#
#
# Time step 7
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 1.3348344445560874
#   Water requested: 1.4286681792194078
#   Updated energy for Buoy 1: 3.6651655554439126
#   Updated water for Buoy 1: 8.571331820780593
# Vessel 2 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 3.6651655554439126
#   Updated water for Buoy 1: 8.571331820780593
#
#
# Time step 8
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 9
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.22564631610840102
#   Water requested: 7.219987722668248
#   Updated energy for Buoy 1: 4.774353683891599
#   Updated water for Buoy 1: 2.7800122773317524
#
#
# Time step 10
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.8493564427131046
#   Water requested: 1.8182496720710062
#   Updated energy for Buoy 1: 4.150643557286895
#   Updated water for Buoy 1: 8.181750327928993
#
#
# Time step 11
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 12
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
# Vessel 2 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 13
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 2.4466126419531236
#   Water requested: 0.07066305219717406
#   Updated energy for Buoy 1: 2.5533873580468764
#   Updated water for Buoy 1: 9.929336947802826
#
#
# Time step 14
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step
# Vessel 2 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 2.5718630092532613
#   Updated water for Buoy 1: 7.240008179774566
#
#
# Time step 46
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 47
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 48
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 49
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
# Vessel 2 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 50
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0

# %% [markdown]
# ## Simulazione con 3 AS con rate orario e boe scariche:
# * 06:00 - 10:00: Rate basso (1 a max_vessels // 3).
# * 10:00 - 18:00: Rate alto (1 a max_vessels).
# * 18:00 - 22:00: Rate basso (1 a max_vessels // 3).
# * 22:00 - 06:00: Rate quasi nullo (0 a 1).
#
# Dove ogni istante k è pari ad un ora.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametri globali
num_autonomous_systems = 3  # numero di sistemi di boe autonomi
n = 3  # numero di boe per ciascun sistema
cr = 4.6  # produzione costante di energia rinnovabile per timestep
kc = 0.05  # parametro di conversione energia-acqua
timesteps = 24  # durata della simulazione in ore
initial_energy = 0  # livello iniziale di energia
initial_water = 0  # livello iniziale di acqua
max_energy = 5  # energia massima accumulabile
min_energy = 0.2 * max_energy  # 20% del totale dell'energia accumulabile
max_water = 10  # acqua massima accumulabile
x2_target = 10  # livello target dell'acqua (usato nelle condizioni)
max_vessels = 10  # numero massimo di natanti che possono arrivare in ciascun timestep

# Funzione per inizializzare i vettori di stato
def initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water):
    systems = []
    for _ in range(num_autonomous_systems):
        x1 = np.zeros((n, timesteps + 1))  # energia accumulata per ciascuna boa
        x2 = np.zeros((n, timesteps + 1))  # acqua accumulata per ciascuna boa
        x1[:, 0] = initial_energy
        x2[:, 0] = initial_water
        systems.append((x1, x2))
    return systems

# Funzione per generare il numero di natanti per ciascun timestep
def generate_num_vessels_per_timestep(timesteps, max_vessels):
    num_vessels = np.zeros(timesteps, dtype=int)
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        if 5 <= k < 10:
            num_vessels[k] = np.random.randint(1, max_vessels // 3 + 1)  # Rate basso
        elif 10 <= k < 18:
            num_vessels[k] = np.random.randint(1, max_vessels + 1)  # Rate alto
        elif 18 <= k < 22:
            num_vessels[k] = np.random.randint(1, max_vessels // 2 + 1)  # Rate basso
        elif 2 <= k < 5:
            num_vessels[k] = 0  # Rate nullo
        else:
            num_vessels[k] = np.random.randint(0, 2)  # Rate quasi nullo

    return num_vessels

# Funzione per generare richieste randomiche
def generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels):
    u1 = np.zeros((max_vessels, timesteps + 1))  # energia richiesta da ciascun natante
    u2 = np.zeros((max_vessels, timesteps + 1))  # acqua richiesta da ciascun natante
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        for i in range(num_vessels[k]):
            max_possible_energy_request = max_energy - min_energy
            u1[i, k] = np.random.uniform(0, max_possible_energy_request)
            u2[i, k] = np.random.uniform(0, max_water)
    return u1, u2

# Funzione per aggiornare lo stato delle boe
def update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water):
    for i in range(n):
        if x1[i, k] / kc < (x2_target - x2[i, k]):
            # Caso 1: La batteria non ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr
            x2[i, k + 1] = x2[i, k] + (x1[i, k] / kc)
        else:
            # Caso 2: La batteria ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr - kc * (x2_target - x2[i, k])
            x2[i, k + 1] = x2_target

        # Assicura che l'energia non superi il massimo
        if x1[i, k + 1] > max_energy:
            x1[i, k + 1] = max_energy

        # Assicura che l'acqua non superi il limite massimo
        if x2[i, k + 1] > max_water:
            x2[i, k + 1] = max_water
    return x1, x2

# Funzione per assegnare le richieste dei natanti ai sistemi di boe
def assign_requests_to_systems(systems, u1, u2, k, num_vessels, min_energy, max_energy, max_water):
    for i in range(num_vessels):
        assigned = False
        for system_index, (x1, x2) in enumerate(systems):
            for j in range(n):
                if (x1[j, k + 1] - u1[i, k] >= min_energy and x1[j, k + 1] - u1[i, k] <= max_energy and
                    x2[j, k + 1] - u2[i, k] >= 0 and x2[j, k + 1] - u2[i, k] <= max_water):
                    # Assegna la richiesta alla boa j del sistema system_index
                    x1[j, k + 1] -= u1[i, k]
                    x2[j, k + 1] -= u2[i, k]

                    # Assicura che l'energia non scenda sotto la soglia minima
                    if x1[j, k + 1] < min_energy:
                        x1[j, k + 1] = min_energy

                    # Assicura che l'acqua non scenda sotto 0
                    if x2[j, k + 1] < 0:
                        x2[j, k + 1] = 0

                    # Stampa le richieste e le risorse aggiornate per la boa assegnata
                    print(f"Vessel {i + 1} assigned to Buoy {j + 1} in System {system_index + 1}:")
                    print(f"  Energy requested: {u1[i, k]}")
                    print(f"  Water requested: {u2[i, k]}")
                    print(f"  Updated energy for Buoy {j + 1} in System {system_index + 1}: {x1[j, k + 1]}")
                    print(f"  Updated water for Buoy {j + 1} in System {system_index + 1}: {x2[j, k + 1]}")
                    assigned = True
                    break
            if assigned:
                break
        
        if not assigned:
            print(f"Vessel {i + 1} could not be assigned at time step {k + 1}")

# Funzione per eseguire la simulazione
def run_simulation_multiple_systems(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels):
    systems = initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water)
    num_vessels = generate_num_vessels_per_timestep(timesteps, max_vessels)
    u1, u2 = generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels)

    for k in range(timesteps):
        print(f"Time step {k + 1}")

        for system_index, (x1, x2) in enumerate(systems):
            systems[system_index] = update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water)
        if num_vessels[k] > 0:
            assign_requests_to_systems(systems, u1, u2, k, num_vessels[k], min_energy, max_energy, max_water)
        print("\n")

    return systems

# Funzione per visualizzare i risultati
def plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water):
    for system_index, (x1, x2) in enumerate(systems):
        print("--------------------------------------------------------------------------------------------------------------")
        plt.figure(figsize=(12, 6))
        
        for i in range(n):
            plt.subplot(2, n, i + 1)
            plt.plot(x1[i], label=f'Accumulated Energy Buoy {i+1} in System {system_index + 1}')
            plt.axhline(min_energy, color='r', linestyle='--', label='Min Energy Threshold')
            plt.axhline(max_energy, color='g', linestyle='--', label='Max Energy Threshold')
            plt.xlabel('Time step')
            plt.ylabel('Energy')
            plt.legend()
            plt.grid(True)

            plt.subplot(2, n, i + 1 + n)
            plt.plot(x2[i], label=f'Accumulated Water Buoy {i+1} in System {system_index + 1}')
            plt.axhline(max_water, color='b', linestyle='--', label='Max Water Threshold')
            plt.xlabel('Time step')
            plt.ylabel('Water')
            plt.legend()
            plt.grid(True)

        plt.tight_layout()
        plt.show()

# Esegui la simulazione con più sistemi di boe
systems = run_simulation_multiple_systems(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels)

# Visualizza i risultati
plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water)
# Out:
# Time step 1
#
#
# Time step 2
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 1: 3.50183952461055
#   Updated water for Buoy 1 in System 1: 0.49285693590083923
#
#
# Time step 3
#
#
# Time step 4
#
#
# Time step 5
#
#
# Time step 6
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametri globali
num_autonomous_systems = 3  # numero di sistemi di boe autonomi
n = 3  # numero di boe per ciascun sistema
cr = 4.6  # produzione costante di energia rinnovabile per timestep
kc = 0.05  # parametro di conversione energia-acqua
timesteps = 24  # durata della simulazione in ore
initial_energy = 5  # livello iniziale di energia
initial_water = 10  # livello iniziale di acqua
max_energy = 5  # energia massima accumulabile
min_energy = 0.2 * max_energy  # 20% del totale dell'energia accumulabile
max_water = 10  # acqua massima accumulabile
x2_target = 10  # livello target dell'acqua (usato nelle condizioni)
max_vessels = 10  # numero massimo di natanti che possono arrivare in ciascun timestep

# Funzione per inizializzare i vettori di stato
def initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water):
    systems = []
    for _ in range(num_autonomous_systems):
        x1 = np.zeros((n, timesteps + 1))  # energia accumulata per ciascuna boa
        x2 = np.zeros((n, timesteps + 1))  # acqua accumulata per ciascuna boa
        x1[:, 0] = initial_energy
        x2[:, 0] = initial_water
        systems.append((x1, x2))
    return systems

# Funzione per generare il numero di natanti per ciascun timestep
def generate_num_vessels_per_timestep(timesteps, max_vessels):
    num_vessels = np.zeros(timesteps, dtype=int)
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        if 6 <= k < 10:
            num_vessels[k] = np.random.randint(1, max_vessels // 3 + 1)  # Rate basso
        elif 10 <= k < 18:
            num_vessels[k] = np.random.randint(1, max_vessels + 1)  # Rate alto
        elif 18 <= k < 22:
            num_vessels[k] = np.random.randint(1, max_vessels // 2 + 1)  # Rate basso
        else:
            num_vessels[k] = np.random.randint(0, 2)  # Rate quasi nullo

    return num_vessels

# Funzione per generare richieste randomiche
def generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels):
    u1 = np.zeros((max_vessels, timesteps + 1))  # energia richiesta da ciascun natante
    u2 = np.zeros((max_vessels, timesteps + 1))  # acqua richiesta da ciascun natante
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        for i in range(num_vessels[k]):
            max_possible_energy_request = max_energy - min_energy
            u1[i, k] = np.random.uniform(0, max_possible_energy_request)
            u2[i, k] = np.random.uniform(0, max_water)
    return u1, u2

# Funzione per aggiornare lo stato delle boe
def update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water):
    for i in range(n):
        if x1[i, k] / kc < (x2_target - x2[i, k]):
            # Caso 1: La batteria non ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr
            x2[i, k + 1] = x2[i, k] + (x1[i, k] / kc)
        else:
            # Caso 2: La batteria ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr - kc * (x2_target - x2[i, k])
            x2[i, k + 1] = x2_target

        # Assicura che l'energia non superi il massimo
        if x1[i, k + 1] > max_energy:
            x1[i, k + 1] = max_energy

        # Assicura che l'acqua non superi il limite massimo
        if x2[i, k + 1] > max_water:
            x2[i, k + 1] = max_water
    return x1, x2

# Funzione per assegnare le richieste dei natanti ai sistemi di boe
def assign_requests_to_systems(systems, u1, u2, k, num_vessels, min_energy, max_energy, max_water):
    for i in range(num_vessels):
        assigned = False
        for system_index, (x1, x2) in enumerate(systems):
            for j in range(n):
                if (x1[j, k + 1] - u1[i, k] >= min_energy and x1[j, k + 1] - u1[i, k] <= max_energy and
                    x2[j, k + 1] - u2[i, k] >= 0 and x2[j, k + 1] - u2[i, k] <= max_water):
                    # Assegna la richiesta alla boa j del sistema system_index
                    x1[j, k + 1] -= u1[i, k]
                    x2[j, k + 1] -= u2[i, k]

                    # Assicura che l'energia non scenda sotto la soglia minima
                    if x1[j, k + 1] < min_energy:
                        x1[j, k + 1] = min_energy

                    # Assicura che l'acqua non scenda sotto 0
                    if x2[j, k + 1] < 0:
                        x2[j, k + 1] = 0

                    # Stampa le richieste e le risorse aggiornate per la boa assegnata
                    print(f"Vessel {i + 1} assigned to Buoy {j + 1} in System {system_index + 1}:")
                    print(f"  Energy requested: {u1[i, k]}")
                    print(f"  Water requested: {u2[i, k]}")
                    print(f"  Updated energy for Buoy {j + 1} in System {system_index + 1}: {x1[j, k + 1]}")
                    print(f"  Updated water for Buoy {j + 1} in System {system_index + 1}: {x2[j, k + 1]}")
                    assigned = True
                    break
            if assigned:
                break
        
        if not assigned:
            print(f"Vessel {i + 1} could not be assigned at time step {k + 1}")

# Funzione per eseguire la simulazione
def run_simulation_multiple_systems(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels):
    systems = initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water)
    num_vessels = generate_num_vessels_per_timestep(timesteps, max_vessels)
    u1, u2 = generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels)

    for k in range(timesteps):
        print(f"Time step {k + 1}")

        for system_index, (x1, x2) in enumerate(systems):
            systems[system_index] = update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water)
        if num_vessels[k] > 0:
            assign_requests_to_systems(systems, u1, u2, k, num_vessels[k], min_energy, max_energy, max_water)
        print("\n")

    return systems

# Funzione per visualizzare i risultati
def plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water):
    time_labels = [f"{(6 + i) % 24:02d}:00" for i in range(timesteps + 1)]
    
    for system_index, (x1, x2) in enumerate(systems):
        print("--------------------------------------------------------------------------------------------------------------")
        plt.figure(figsize=(12, 6))
        
        for i in range(n):
            plt.subplot(2, n, i + 1)
            plt.plot(x1[i], label=f'Accumulated Energy Buoy {i+1} in System {system_index + 1}')
            plt.axhline(min_energy, color='r', linestyle='--', label='Min Energy Threshold')
            plt.axhline(max_energy, color='g', linestyle='--', label='Max Energy Threshold')
            plt.xlabel('Time')
            plt.ylabel('Energy')
            plt.xticks(ticks=range(0, timesteps + 1, 2), labels=time_labels[::2], rotation=45)
            plt.legend()
            plt.grid(True)

            plt.subplot(2, n, i + 1 + n)
            plt.plot(x2[i], label=f'Accumulated Water Buoy {i+1} in System {system_index + 1}')
            plt.axhline(max_water, color='b', linestyle='--', label='Max Water Threshold')
            plt.xlabel('Time')
            plt.ylabel('Water')
            plt.xticks(ticks=range(0, timesteps + 1, 2), labels=time_labels[::2], rotation=45)
            plt.legend()
            plt.grid(True)

        plt.tight_layout()
        plt.show()

# Esegui la simulazione con più sistemi di boe
systems = run_simulation_multiple_systems(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels)

# Visualizza i risultati
plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water)
# Out:
# Time step 1
#
#
# Time step 2
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 1: 3.50183952461055
#   Updated water for Buoy 1 in System 1: 0.49285693590083923
#
#
# Time step 3
#
#
# Time step 4
#
#
# Time step 5
#
#
# Time step 6
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 1 in System 1: 2.0720242327543796
#   Updated water for Buoy 1 in System 1: 4.013415158029634
#
#
# Time step 7
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 1 in System 1: 4.375925438230254
#   Updated water for Buoy 1 in System 1: 8.440054796637973
#
#
# Time step 8
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
# Vessel 2 assigned to Buoy 2 in System 1:
#   Energy requested: 3.2720590636899725
#   Water requested: 8.607305832563434
#   Updated energy for Buoy 2 in System 1: 1.7279409363100275
#   Updated water for Buoy 2 in System 1: 1.3926941674365665
# Vessel 3 assigned to Buoy 1 in System 1:
#   Energy requested: 0.027808522124762813
#   Water requested: 5.107473025775658
#   Updated energy for Buoy 1 in System 1: 4.06045082770747
#   Updated water for Buoy 1 in System 1: 0.6214490879617793
# Vessel 4 assigned to Buoy 3 in System 1:
#   Energy requested: 1.669644012595116
#   Water requested: 2.2210781047073027
#   Updated energy for Buoy 3 in System 1: 3.330355987404884
#   Updated water for Buoy 3 in System 1: 7.778921895292697
#
#
# Time step 22
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 0.4794614693347312
#   Water requested: 3.3761517140362796
#   Updated energy for Buoy 1 in System 1: 4.520538530665268
#   Updated water for Buoy 1 in System 1: 6.623848285963721
# Vessel 2 assigned to Buoy 2 in System 1:
#   Energy requested: 3.7716388156500766
#   Water requested: 3.2320293202075523
#   Updated energy for Buoy 2 in System 1: 1.2283611843499234
#   Updated water for Buoy 2 in System 1: 6.767970679792448
#
#
# Time step 23
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 2.0751624869734644
#   Water requested: 7.030189588951778
#   Updated energy for Buoy 1 in System 1: 2.9248375130265356
#   Updated water for Buoy 1 in System 1: 2.969810411048222
#
#
# Time step 24
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 1.454518409517176
#   Water requested: 9.717820827209607
#   Updated energy for Buoy 1 in System 1: 3.545481590482824
#   Updated water for Buoy 1 in System 1: 0.28217917279039284
#
#
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # VERSIONE CON ASSEGNAZIONE ROUND-ROBIN

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametri globali
n = 3  # numero di boe
cr = 4.6  # produzione costante di energia rinnovabile per timestep
kc = 0.05  # parametro di conversione energia-acqua
timesteps = 50  # durata della simulazione
initial_energy = 0  # livello iniziale di energia
initial_water = 0  # livello iniziale di acqua
max_energy = 5  # energia massima accumulabile
min_energy = 0.2 * max_energy  # 20% del totale dell'energia accumulabile
max_water = 10  # acqua massima accumulabile
x2_target = 10  # livello target dell'acqua (usato nelle condizioni)
max_vessels = 2  # numero massimo di natanti che possono arrivare in ciascun timestep

# Funzione per inizializzare i vettori di stato
def initialize_state_vectors(n, timesteps, initial_energy, initial_water):
    x1 = np.zeros((n, timesteps + 1))  # energia accumulata per ciascuna boa
    x2 = np.zeros((n, timesteps + 1))  # acqua accumulata per ciascuna boa
    x1[:, 0] = initial_energy
    x2[:, 0] = initial_water
    return x1, x2

# Funzione per generare richieste randomiche
def generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water):
    u1 = np.zeros((max_vessels, timesteps + 1))  # energia richiesta da ciascun natante
    u2 = np.zeros((max_vessels, timesteps + 1))  # acqua richiesta da ciascun natante
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        num_vessels = np.random.randint(0, max_vessels)  # numero di natanti al timestep k
        for i in range(num_vessels):
            max_possible_energy_request = max_energy - min_energy
            u1[i, k] = np.random.uniform(0, max_possible_energy_request)
            u2[i, k] = np.random.uniform(0, max_water)
    return u1, u2

# Funzione per aggiornare lo stato delle boe
def update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water):
    for i in range(n):
        if x1[i, k] / kc < (x2_target - x2[i, k]):
            # Caso 1: La batteria non ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr
            x2[i, k + 1] = x2[i, k] + (x1[i, k] / kc)
        else:
            # Caso 2: La batteria ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr - kc * (x2_target - x2[i, k])
            x2[i, k + 1] = x2_target

        # Assicura che l'energia non superi il massimo
        if x1[i, k + 1] > max_energy:
            x1[i, k + 1] = max_energy

        # Assicura che l'acqua non superi il limite massimo
        if x2[i, k + 1] > max_water:
            x2[i, k + 1] = max_water
    return x1, x2

# Funzione per assegnare le richieste dei natanti alle boe utilizzando round robin
def assign_requests_round_robin(x1, x2, u1, u2, k, num_vessels, min_energy, max_energy, max_water, last_assigned_buoy):
    for i in range(num_vessels):
        assigned = False
        for _ in range(n):
            j = (last_assigned_buoy + 1) % n
            if (x1[j, k + 1] - u1[i, k] >= min_energy and x1[j, k + 1] - u1[i, k] <= max_energy and
                x2[j, k + 1] - u2[i, k] >= 0 and x2[j, k + 1] - u2[i, k] <= max_water):
                # Assegna la richiesta alla boa j
                x1[j, k + 1] -= u1[i, k]
                x2[j, k + 1] -= u2[i, k]

                # Assicura che l'energia non scenda sotto la soglia minima
                if x1[j, k + 1] < min_energy:
                    x1[j, k + 1] = min_energy

                # Assicura che l'acqua non scenda sotto 0
                if x2[j, k + 1] < 0:
                    x2[j, k + 1] = 0

                # Stampa le richieste e le risorse aggiornate per la boa assegnata
                print(f"Vessel {i + 1} assigned to Buoy {j + 1}:")
                print(f"  Energy requested: {u1[i, k]}")
                print(f"  Water requested: {u2[i, k]}")
                print(f"  Updated energy for Buoy {j + 1}: {x1[j, k + 1]}")
                print(f"  Updated water for Buoy {j + 1}: {x2[j, k + 1]}")
                assigned = True
                last_assigned_buoy = j
                break
        
        if not assigned:
            print(f"Vessel {i + 1} could not be assigned at time step {k + 1}")
    
    return last_assigned_buoy

# Funzione per eseguire la simulazione
def run_simulation_round_robin(n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels):
    x1, x2 = initialize_state_vectors(n, timesteps, initial_energy, initial_water)
    u1, u2 = generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water)
    last_assigned_buoy = -1  # inizializza l'ultima boa assegnata

    for k in range(timesteps):
        print(f"Time step {k + 1}")
        num_vessels = np.random.randint(1, max_vessels + 1)  # numero di natanti al timestep k
        x1, x2 = update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water)
        last_assigned_buoy = assign_requests_round_robin(x1, x2, u1, u2, k, num_vessels, min_energy, max_energy, max_water, last_assigned_buoy)
        print("\n")

    return x1, x2

# Funzione per visualizzare i risultati
def plot_results(x1, x2, n, timesteps, min_energy, max_energy, max_water):
    plt.figure(figsize=(12, 6))

    for i in range(n):
        plt.subplot(n, 2, 2 * i + 1)
        plt.plot(x1[i], label=f'Accumulated Energy Buoy {i+1}')
        plt.axhline(min_energy, color='r', linestyle='--', label='Min Energy Threshold')
        plt.axhline(max_energy, color='g', linestyle='--', label='Max Energy Threshold')
        plt.xlabel('Time step')
        plt.ylabel('Energy')
        plt.legend()
        plt.grid(True)

        plt.subplot(n, 2, 2 * i + 2)
        plt.plot(x2[i], label=f'Accumulated Water Buoy {i+1}')
        plt.axhline(max_water, color='b', linestyle='--', label='Max Water Threshold')
        plt.xlabel('Time step')
        plt.ylabel('Water')
        plt.legend()
        plt.grid(True)

    plt.tight_layout()
    plt.show()

# Esegui la simulazione con assegnazione round robin
x1, x2 = run_simulation_round_robin(n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels)

# Visualizza i risultati
plot_results(x1, x2, n, timesteps, min_energy, max_energy, max_water)
# Out:
# Time step 1
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 4.6
#   Updated water for Buoy 1: 0.0
#
#
# Time step 2
# Vessel 1 assigned to Buoy 2:
#   Energy requested: 3.8028572256396647
#   Water requested: 7.319939418114051
#   Updated energy for Buoy 2: 1.1971427743603353
#   Updated water for Buoy 2: 2.6800605818859493
#
#
# Time step 3
# Vessel 1 assigned to Buoy 3:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 3: 5.0
#   Updated water for Buoy 3: 10.0
# Vessel 2 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step
# Vessel 1 assigned to Buoy 3:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 3: 5.0
#   Updated water for Buoy 3: 10.0
#
#
# Time step 41
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 2.2817758976215976
#   Water requested: 5.208342600258237
#   Updated energy for Buoy 1: 2.7182241023784024
#   Updated water for Buoy 1: 4.791657399741763
#
#
# Time step 42
# Vessel 1 assigned to Buoy 2:
#   Energy requested: 1.3013213230530574
#   Water requested: 3.8867728968948203
#   Updated energy for Buoy 2: 3.6986786769469426
#   Updated water for Buoy 2: 6.11322710310518
#
#
# Time step 43
# Vessel 1 assigned to Buoy 3:
#   Energy requested: 2.158768529556319
#   Water requested: 5.867511656638483
#   Updated energy for Buoy 3: 2.841231470443681
#   Updated water for Buoy 3: 4.132488343361517
#
#
# Time step 44
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 45
# Vessel 1 assigned to Buoy 2:
#   Energy requested: 2.4281369907467387
#   Water requested: 2.7599918202254337
#   Updated energy for Buoy 2: 2.5718630092532613
#   Updated water for Buoy 2: 7.240008179774566
# Vessel 2 assigned to Buoy 3:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 3: 5.0
#   Updated water for Buoy 3: 10.0
#
#
# Time step 46
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
#
#
# Time step 47
# Vessel 1 assigned to Buoy 2:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 2: 5.0
#   Updated water for Buoy 2: 10.0
#
#
# Time step 48
# Vessel 1 assigned to Buoy 3:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 3: 5.0
#   Updated water for Buoy 3: 10.0
#
#
# Time step 49
# Vessel 1 assigned to Buoy 1:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 1: 5.0
#   Updated water for Buoy 1: 10.0
# Vessel 2 assigned to Buoy 2:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 2: 5.0
#   Updated water for Buoy 2: 10.0
#
#
# Time step 50
# Vessel 1 assigned to Buoy 3:
#   Energy requested: 0.0
#   Water requested: 0.0
#   Updated energy for Buoy 3: 5.0
#   Updated water for Buoy 3: 10.0

# %% [markdown]
# ## Simulazione con 3 AS con assegnazione round robin con rate orario (boe scariche):
# * 02:00 - 05:00: Rate nullo (0)
# * 05:00 - 10:00: Rate basso (1 a max_vessels // 3).
# * 10:00 - 18:00: Rate alto (1 a max_vessels).
# * 18:00 - 22:00: Rate basso (1 a max_vessels // 3).
# * 22:00 - 06:00: Rate quasi nullo (0 a 1).
#
# Dove ogni istante k è pari ad un ora.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametri globali
num_autonomous_systems = 3  # numero di sistemi di boe autonomi
n = 3  # numero di boe per ciascun sistema
cr = 4.6  # produzione costante di energia rinnovabile per timestep
kc = 0.05  # parametro di conversione energia-acqua
timesteps = 24  # durata della simulazione in ore
initial_energy = 0  # livello iniziale di energia
initial_water = 0  # livello iniziale di acqua
max_energy = 5  # energia massima accumulabile
min_energy = 0.2 * max_energy  # 20% del totale dell'energia accumulabile
max_water = 10  # acqua massima accumulabile
x2_target = 10  # livello target dell'acqua (usato nelle condizioni)
max_vessels = 10  # numero massimo di natanti che possono arrivare in ciascun timestep

# Funzione per inizializzare i vettori di stato
def initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water):
    systems = []
    for _ in range(num_autonomous_systems):
        x1 = np.zeros((n, timesteps + 1))  # energia accumulata per ciascuna boa
        x2 = np.zeros((n, timesteps + 1))  # acqua accumulata per ciascuna boa
        x1[:, 0] = initial_energy
        x2[:, 0] = initial_water
        systems.append((x1, x2))
    return systems

# Funzione per generare il numero di natanti per ciascun timestep
def generate_num_vessels_per_timestep(timesteps, max_vessels):
    num_vessels = np.zeros(timesteps, dtype=int)
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        if 5 <= k < 10:
            num_vessels[k] = np.random.randint(1, max_vessels // 3 + 1)  # Rate basso
        elif 10 <= k < 18:
            num_vessels[k] = np.random.randint(1, max_vessels + 1)  # Rate alto
        elif 18 <= k < 22:
            num_vessels[k] = np.random.randint(1, max_vessels // 2 + 1)  # Rate basso
        elif 2 <= k < 5:
            num_vessels[k] = 0  # Rate nullo
        else:
            num_vessels[k] = np.random.randint(0, 2)  # Rate quasi nullo

    return num_vessels

# Funzione per generare richieste randomiche
def generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels):
    u1 = np.zeros((max_vessels, timesteps + 1))  # energia richiesta da ciascun natante
    u2 = np.zeros((max_vessels, timesteps + 1))  # acqua richiesta da ciascun natante
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        for i in range(num_vessels[k]):
            max_possible_energy_request = max_energy - min_energy
            u1[i, k] = np.random.uniform(0, max_possible_energy_request)
            u2[i, k] = np.random.uniform(0, max_water)
    return u1, u2

# Funzione per aggiornare lo stato delle boe
def update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water):
    for i in range(n):
        if x1[i, k] / kc < (x2_target - x2[i, k]):
            # Caso 1: La batteria non ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr
            x2[i, k + 1] = x2[i, k] + (x1[i, k] / kc)
        else:
            # Caso 2: La batteria ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr - kc * (x2_target - x2[i, k])
            x2[i, k + 1] = x2_target

        # Assicura che l'energia non superi il massimo
        if x1[i, k + 1] > max_energy:
            x1[i, k + 1] = max_energy

        # Assicura che l'acqua non superi il limite massimo
        if x2[i, k + 1] > max_water:
            x2[i, k + 1] = max_water
    return x1, x2

# Funzione per assegnare le richieste dei natanti alle boe utilizzando round robin
def assign_requests_round_robin(systems, u1, u2, k, num_vessels, min_energy, max_energy, max_water, last_assigned_buoy):
    for i in range(num_vessels):
        assigned = False
        initial_system = last_assigned_buoy // n  # Inizia dal sistema dell'ultima boa assegnata
        for system_offset in range(num_autonomous_systems):
            system_index = (initial_system + system_offset) % num_autonomous_systems
            x1, x2 = systems[system_index]
            for _ in range(n):
                j = (last_assigned_buoy + 1) % n
                if (x1[j, k + 1] - u1[i, k] >= min_energy and x1[j, k + 1] - u1[i, k] <= max_energy and
                    x2[j, k + 1] - u2[i, k] >= 0 and x2[j, k + 1] - u2[i, k] <= max_water):
                    # Assegna la richiesta alla boa j del sistema system_index
                    x1[j, k + 1] -= u1[i, k]
                    x2[j, k + 1] -= u2[i, k]

                    # Assicura che l'energia non scenda sotto la soglia minima
                    if x1[j, k + 1] < min_energy:
                        x1[j, k + 1] = min_energy

                    # Assicura che l'acqua non scenda sotto 0
                    if x2[j, k + 1] < 0:
                        x2[j, k + 1] = 0

                    # Stampa le richieste e le risorse aggiornate per la boa assegnata
                    print(f"Vessel {i + 1} assigned to Buoy {j + 1} in System {system_index + 1}:")
                    print(f"  Energy requested: {u1[i, k]}")
                    print(f"  Water requested: {u2[i, k]}")
                    print(f"  Updated energy for Buoy {j + 1} in System {system_index + 1}: {x1[j, k + 1]}")
                    print(f"  Updated water for Buoy {j + 1} in System {system_index + 1}: {x2[j, k + 1]}")
                    assigned = True
                    last_assigned_buoy = j + system_index * n
                    break
            if assigned:
                break
        
        if not assigned:
            print(f"Vessel {i + 1} could not be assigned at time step {k + 1}")
    
    return last_assigned_buoy

# Funzione per eseguire la simulazione
def run_simulation_round_robin(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels):
    systems = initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water)
    num_vessels = generate_num_vessels_per_timestep(timesteps, max_vessels)
    u1, u2 = generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels)
    last_assigned_buoy = -1  # inizializza l'ultima boa assegnata

    for k in range(timesteps):
        print(f"Time step {k + 1}")
        
        for system_index, (x1, x2) in enumerate(systems):
            systems[system_index] = update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water)
        
        for i in range(num_vessels[k]):
            print(f"Vessel {i + 1} arriving:")
            print(f"  Energy requested: {u1[i, k]}")
            print(f"  Water requested: {u2[i, k]}")
        
        if num_vessels[k] > 0:
            last_assigned_buoy = assign_requests_round_robin(systems, u1, u2, k, num_vessels[k], min_energy, max_energy, max_water, last_assigned_buoy)
        print("\n")

    return systems

# Funzione per visualizzare i risultati
def plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water):
    for system_index, (x1, x2) in enumerate(systems):
        print("--------------------------------------------------------------------------------------------------------------")
        plt.figure(figsize=(12, 6))
        
        for i in range(n):
            plt.subplot(2, n, i + 1)
            plt.plot(x1[i], label=f'Accumulated Energy Buoy {i+1} in System {system_index + 1}')
            plt.axhline(min_energy, color='r', linestyle='--', label='Min Energy Threshold')
            plt.axhline(max_energy, color='g', linestyle='--', label='Max Energy Threshold')
            plt.xlabel('Time step')
            plt.ylabel('Energy')
            plt.legend()
            plt.grid(True)

            plt.subplot(2, n, i + 1 + n)
            plt.plot(x2[i], label=f'Accumulated Water Buoy {i+1} in System {system_index + 1}')
            plt.axhline(max_water, color='b', linestyle='--', label='Max Water Threshold')
            plt.xlabel('Time step')
            plt.ylabel('Water')
            plt.legend()
            plt.grid(True)

        plt.tight_layout()
        plt.show()

# Esegui la simulazione con assegnazione round robin
systems = run_simulation_round_robin(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels)

# Visualizza i risultati
plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water)
# Out:
# Time step 1
#
#
# Time step 2
# Vessel 1 arriving:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 3: 3.50183952461055
#   Updated water for Buoy 1 in System 3: 0.49285693590083923
#
#
# Time step 3
#
#
# Time step 4
#
#
# Time step 5
#
#
# Time step 6
# Vessel 1 arriving:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
# Vessel 1 assigned to Buoy 2 in System 3:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 2 in System 3: 2.0720242327543796
#   Updated water for Buoy 2 in System 3: 4.013415158029634
#
#
# Time step 7
# Vessel 1 arriving:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
# Vessel 2 arriving:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
# Vessel 3 arriving:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
# Vessel 1 assigned to Buoy 3 in System 3:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 3 in System 3: 4.375925438230254
#   Updated water for Buoy 3 in System 3: 8.440054796637973
# Vessel 2 assigned to Buoy 1 in System 3:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
#   Updated energy for Buoy 1 in System 3: 4.767665551327202
#   Updated water for Buoy 1 in System 3: 1.3382385422506484
# Vessel 3 assigned to Buoy 2 in System 3:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
#   Updated energy for Buoy 2 in System 3: 2.595539953027165
#   Updated water for Buoy 2 in System 3: 2.9192742220395456
#
#
# Time step 8
# Vessel 1 arriving:
#   Energy requested: 0.08233797718320979
#   Water requested: 9.699098521619943
# Vessel 2 arriving:
#   Energy requested: 3.329770563201687
#   Water requested: 2.1233911067827616
# Vessel 3 arriving:
#   Energy requested: 0.7272998688284025
#   Water requested: 1.8340450985343382
# Vessel 1 assigned to Buoy 3 in System 3:
#   Energy requested: 0.08233797718320979
#   Water requested: 9.699098521619943
#   Updated energy for Buoy 3 in System 3: 4.91766202281679
#   Updated water for Buoy 3 in System 3: 0.300901478380057
# Vessel 2 assigned to Buoy 1 in System 3:
#   Energy requested: 3.329770563201687
#   Water requested: 2.1233911067827616
#   Updated energy for Buoy 1 in System 3: 1.670229436798313
#   Updated water for Buoy 1 in System 3: 7.876608893217238
# Vessel 3 assigned to Buoy 2 in System 3:
#   Energy requested: 0.7272998688284025
#   Water requested: 1.8340450985343382
#   Updated energy for Buoy 2 in System 3: 4.2727001311715975
#   Updated water for Buoy 2 in System 3: 8.165954901465662
#
#
# Time step 9
# Vessel 1 arriving:
#   Energy requested: 1.216968971838151
#   Water requested: 5.247564316322379
# Vessel 1 assigned to Buoy 3 in System 3:
#   Energy requested: 1.216968971838151
#   Water requested: 5.247564316322379
#   Updated energy for Buoy 3 in System 3: 3.783031028161849
#   Updated water for Buoy 3 in System 3: 4.752435683677621
#
#
# Time step 10
# Vessel 1 arriving:
#   Energy requested: 1.727780074568463
#   Water requested: 2.9122914019804194
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 1.727780074568463
#   Water requested: 2.9122914019804194
#   Updated energy for Buoy 1 in System 3: 3.272219925431537
#   Updated water for Buoy 1 in System 3: 7.087708598019581
#
#
# Time step 11
# Vessel 1 arriving:
#   Energy requested: 2.447411578889518
#   Water requested: 1.3949386065204183
# Vessel 2 arriving:
#   Energy requested: 1.1685785941408726
#   Water requested: 3.663618432936917
# Vessel 3 arriving:
#   Energy requested: 1.8242799368681437
#   Water requested: 7.851759613930136
# Vessel 4 arriving:
#   Energy requested: 0.7986951286334389
#   Water requested: 5.142344384136116
# Vessel 5 arriving:
#   Energy requested: 2.36965827544817
#   Water requested: 0.46450412719997725
# Vessel 6 arriving:
#   Energy requested: 2.4301794076057535
#   Water requested: 1.7052412368729153
# Vessel 7 arriving:
#   Energy requested: 0.26020637194111806
#   Water requested: 9.488855372533333
# Vessel 1 assigned to Buoy 2 in System 3:
#   Energy requested: 2.447411578889518
#   Water requested: 1.3949386065204183
#   Updated energy for Buoy 2 in System 3: 2.552588421110482
#   Updated water for Buoy 2 in System 3: 8.605061393479582
# Vessel 2 assigned to Buoy 3 in System 3:
#   Energy requested: 1.1685785941408726
#   Water requested: 3.663618432936917
#   Updated energy for Buoy 3 in System 3: 3.8314214058591274
#   Updated water for Buoy 3 in System 3: 6.336381567063083
# Vessel 3 assigned to Buoy 1 in System 3:
#   Energy requested: 1.8242799368681437
#   Water requested: 7.851759613930136
#   Updated energy for Buoy 1 in System 3: 3.1757200631318563
#   Updated water for Buoy 1 in System 3: 2.1482403860698636
# Vessel 4 assigned to Buoy 2 in System 3:
#   Energy requested: 0.7986951286334389
#   Water requested: 5.142344384136116
#   Updated energy for Buoy 2 in System 3: 1.7538932924770432
#   Updated water for Buoy 2 in System 3: 3.462717009343466
# Vessel 5 assigned to Buoy 3 in System 3:
#   Energy requested: 2.36965827544817
#   Water requested: 0.46450412719997725
#   Updated energy for Buoy 3 in System 3: 1.4617631304109575
#   Updated water for Buoy 3 in System 3: 5.8718774398631055
# Vessel 6 assigned to Buoy 1 in System 1:
#   Energy requested: 2.4301794076057535
#   Water requested: 1.7052412368729153
#   Updated energy for Buoy 1 in System 1: 2.5698205923942465
#   Updated water for Buoy 1 in System 1: 8.294758763127085
# Vessel 7 assigned to Buoy 2 in System 1:
#   Energy requested: 0.26020637194111806
#   Water requested: 9.488855372533333
#   Updated energy for Buoy 2 in System 1: 4.739793628058882
#   Updated water for Buoy 2 in System 1: 0.5111446274666669
#
#
# Time step 12
# Vessel 1 arriving:
#   Energy requested: 3.8625281322982374
#   Water requested: 8.08397348116461
# Vessel 2 arriving:
#   Energy requested: 1.2184550766934827
#   Water requested: 0.9767211400638387
# Vessel 3 arriving:
#   Energy requested: 2.7369321060486276
#   Water requested: 4.4015249373960135
# Vessel 4 arriving:
#   Energy requested: 0.4881529393791153
#   Water requested: 4.951769101112702
# Vessel 5 arriving:
#   Energy requested: 0.13755408446087358
#   Water requested: 9.093204020787821
# Vessel 6 arriving:
#   Energy requested: 1.0351199264000677
#   Water requested: 6.62522284353982
# Vessel 7 arriving:
#   Energy requested: 1.2468443043576438
#   Water requested: 5.200680211778108
# Vessel 8 arriving:
#   Energy requested: 2.1868411173731186
#   Water requested: 1.8485445552552704
# Vessel 9 arriving:
#   Energy requested: 3.8783385110582342
#   Water requested: 7.7513282336111455
# Vessel 10 arriving:
#   Energy requested: 3.7579957662567565
#   Water requested: 8.948273504276488
# Vessel 1 assigned to Buoy 3 in System 1:
#   Energy requested: 3.8625281322982374
#   Water requested: 8.08397348116461
#   Updated energy for Buoy 3 in System 1: 1.1374718677017626
#   Updated water for Buoy 3 in System 1: 1.9160265188353893
# Vessel 2 assigned to Buoy 1 in System 1:
#   Energy requested: 1.2184550766934827
#   Water requested: 0.9767211400638387
#   Updated energy for Buoy 1 in System 1: 3.7815449233065173
#   Updated water for Buoy 1 in System 1: 9.02327885993616
# Vessel 3 assigned to Buoy 2 in System 1:
#   Energy requested: 2.7369321060486276
#   Water requested: 4.4015249373960135
#   Updated energy for Buoy 2 in System 1: 2.2630678939513724
#   Updated water for Buoy 2 in System 1: 5.5984750626039865
# Vessel 4 assigned to Buoy 3 in System 2:
#   Energy requested: 0.4881529393791153
#   Water requested: 4.951769101112702
#   Updated energy for Buoy 3 in System 2: 4.511847060620885
#   Updated water for Buoy 3 in System 2: 5.048230898887298
# Vessel 5 assigned to Buoy 1 in System 2:
#   Energy requested: 0.13755408446087358
#   Water requested: 9.093204020787821

#   Energy requested: 0.022088468494409597
#   Water requested: 8.154614284548341
#   Updated energy for Buoy 3 in System 2: 4.97791153150559
#   Updated water for Buoy 3 in System 2: 1.845385715451659
#
#
# Time step 15
# Vessel 1 arriving:
#   Energy requested: 2.8274293753904685
#   Water requested: 7.2900716804098735
# Vessel 2 arriving:
#   Energy requested: 3.085081386743783
#   Water requested: 0.7404465173409036
# Vessel 3 arriving:
#   Energy requested: 1.4338629141770904
#   Water requested: 1.1586905952512971
# Vessel 4 arriving:
#   Energy requested: 3.452413703502374
#   Water requested: 6.232981268275579
# Vessel 5 arriving:
#   Energy requested: 1.3235920994105967
#   Water requested: 0.6355835028602363
# Vessel 6 arriving:
#   Energy requested: 1.2439292868626488
#   Water requested: 3.2518332202674705
# Vessel 7 arriving:
#   Energy requested: 2.9184247133522563
#   Water requested: 6.3755747135521315
# Vessel 8 arriving:
#   Energy requested: 3.548850970305306
#   Water requested: 4.722149251619493
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 2.8274293753904685
#   Water requested: 7.2900716804098735
#   Updated energy for Buoy 1 in System 2: 2.1725706246095315
#   Updated water for Buoy 1 in System 2: 2.7099283195901265
# Vessel 2 assigned to Buoy 2 in System 2:
#   Energy requested: 3.085081386743783
#   Water requested: 0.7404465173409036
#   Updated energy for Buoy 2 in System 2: 1.914918613256217
#   Updated water for Buoy 2 in System 2: 9.259553482659097
# Vessel 3 assigned to Buoy 3 in System 2:
#   Energy requested: 1.4338629141770904
#   Water requested: 1.1586905952512971
#   Updated energy for Buoy 3 in System 2: 3.5661370858229096
#   Updated water for Buoy 3 in System 2: 8.841309404748703
# Vessel 4 assigned to Buoy 1 in System 3:
#   Energy requested: 3.452413703502374
#   Water requested: 6.232981268275579
#   Updated energy for Buoy 1 in System 3: 1.547586296497626
#   Updated water for Buoy 1 in System 3: 3.767018731724421
# Vessel 5 assigned to Buoy 2 in System 3:
#   Energy requested: 1.3235920994105967
#   Water requested: 0.6355835028602363
#   Updated energy for Buoy 2 in System 3: 3.6764079005894033
#   Updated water for Buoy 2 in System 3: 9.364416497139764
# Vessel 6 assigned to Buoy 3 in System 3:
#   Energy requested: 1.2439292868626488
#   Water requested: 3.2518332202674705
#   Updated energy for Buoy 3 in System 3: 3.756070713137351
#   Updated water for Buoy 3 in System 3: 6.7481667797325295
# Vessel 7 assigned to Buoy 1 in System 1:
#   Energy requested: 2.9184247133522563
#   Water requested: 6.3755747135521315
#   Updated energy for Buoy 1 in System 1: 2.0815752866477437
#   Updated water for Buoy 1 in System 1: 3.6244252864478685
# Vessel 8 assigned to Buoy 2 in System 1:
#   Energy requested: 3.548850970305306
#   Water requested: 4.722149251619493
#   Updated energy for Buoy 2 in System 1: 1.4511490296946938
#   Updated water for Buoy 2 in System 1: 5.277850748380507
#
#
# Time step 16
# Vessel 1 arriving:
#   Energy requested: 0.4783769837532068
#   Water requested: 7.13244787222995
# Vessel 2 arriving:
#   Energy requested: 3.0431401944675898
#   Water requested: 5.612771975694963
# Vessel 3 arriving:
#   Energy requested: 3.083868719818244
#   Water requested: 4.937955963643907
# Vessel 4 arriving:
#   Energy requested: 2.0909313175279762
#   Water requested: 4.275410183585496
# Vessel 5 arriving:
#   Energy requested: 0.10167650697638075
#   Water requested: 1.0789142699330445
# Vessel 1 assigned to Buoy 3 in System 1:
#   Energy requested: 0.4783769837532068
#   Water requested: 7.13244787222995
#   Updated energy for Buoy 3 in System 1: 4.521623016246793
#   Updated water for Buoy 3 in System 1: 2.8675521277700504
# Vessel 2 assigned to Buoy 1 in System 1:
#   Energy requested: 3.0431401944675898
#   Water requested: 5.612771975694963
#   Updated energy for Buoy 1 in System 1: 1.9568598055324102
#   Updated water for Buoy 1 in System 1: 4.387228024305037
# Vessel 3 assigned to Buoy 2 in System 1:
#   Energy requested: 3.083868719818244
#   Water requested: 4.937955963643907
#   Updated energy for Buoy 2 in System 1: 1.916131280181756
#   Updated water for Buoy 2 in System 1: 5.062044036356093
# Vessel 4 assigned to Buoy 3 in System 2:
#   Energy requested: 2.0909313175279762
#   Water requested: 4.275410183585496
#   Updated energy for Buoy 3 in System 2: 2.9090686824720238
#   Updated water for Buoy 3 in System 2: 5.724589816414504
# Vessel 5 assigned to Buoy 1 in System 2:
#   Energy requested: 0.10167650697638075
#   Water requested: 1.0789142699330445
#   Updated energy for Buoy 1 in System 2: 4.89832349302362
#   Updated water for Buoy 1 in System 2: 8.921085730066956
#
#
# Time step 17
# Vessel 1 arriving:
#   Energy requested: 0.125716742746937
#   Water requested: 6.364104112637804
# Vessel 2 arriving:
#   Energy requested: 1.2574239243053067
#   Water requested: 5.085706911647028
# Vessel 3 arriving:
#   Energy requested: 3.630265895704372
#   Water requested: 2.4929222914887497
# Vessel 4 arriving:
#   Energy requested: 1.641531692142519
#   Water requested: 7.555511385430487
# Vessel 1 assigned to Buoy 2 in System 2:
#   Energy requested: 0.125716742746937
#   Water requested: 6.364104112637804
#   Updated energy for Buoy 2 in System 2: 4.874283257253063
#   Updated water for Buoy 2 in System 2: 3.635895887362196
# Vessel 2 assigned to Buoy 3 in System 2:
#   Energy requested: 1.2574239243053067
#   Water requested: 5.085706911647028
#   Updated energy for Buoy 3 in System 2: 3.7425760756946933
#   Updated water for Buoy 3 in System 2: 4.914293088352972
# Vessel 3 assigned to Buoy 1 in System 2:
#   Energy requested: 3.630265895704372
#   Water requested: 2.4929222914887497
#   Updated energy for Buoy 1 in System 2: 1.369734104295628
#   Updated water for Buoy 1 in System 2: 7.50707770851125
# Vessel 4 assigned to Buoy 2 in System 3:
#   Energy requested: 1.641531692142519
#   Water requested: 7.555511385430487
#   Updated energy for Buoy 2 in System 3: 3.358468307857481
#   Updated water for Buoy 2 in System 3: 2.4444886145695133
#
#
# Time step 18
# Vessel 1 arriving:
#   Energy requested: 0.9151926619664899
#   Water requested: 0.7697990982879299
# Vessel 2 arriving:
#   Energy requested: 1.159005811655072
#   Water requested: 1.6122128725400442
# Vessel 3 arriving:
#   Energy requested: 3.7187906093702923
#   Water requested: 8.08120379564417
# Vessel 4 arriving:
#   Energy requested: 2.533615026041694
#   Water requested: 8.714605901877178
# Vessel 5 arriving:
#   Energy requested: 3.214688307596458
#   Water requested: 1.8657005888603584
# Vessel 6 arriving:
#   Energy requested: 3.570235993959911
#   Water requested: 5.393422419156507
# Vessel 7 arriving:
#   Energy requested: 3.22976062065625
#   Water requested: 8.960912999234932
# Vessel 8 arriving:
#   Energy requested: 1.2720138998874555
#   Water requested: 1.1005192452767676
# Vessel 1 assigned to Buoy 3 in System 3:
#   Energy requested: 0.9151926619664899
#   Water requested: 0.7697990982879299
#   Updated energy for Buoy 3 in System 3: 4.08480733803351
#   Updated water for Buoy 3 in System 3: 9.23020090171207
# Vessel 2 assigned to Buoy 1 in System 3:
#   Energy requested: 1.159005811655072
#   Water requested: 1.6122128725400442
#   Updated energy for Buoy 1 in System 3: 3.840994188344928
#   Updated water for Buoy 1 in System 3: 8.387787127459955
# Vessel 3 assigned to Buoy 2 in System 3:
#   Energy requested: 3.7187906093702923
#   Water requested: 8.08120379564417
#   Updated energy for Buoy 2 in System 3: 1.2812093906297077
#   Updated water for Buoy 2 in System 3: 1.9187962043558304
# Vessel 4 assigned to Buoy 3 in System 3:
#   Energy requested: 2.533615026041694
#   Water requested: 8.714605901877178
#   Updated energy for Buoy 3 in System 3: 1.5511923119918163
#   Updated water for Buoy 3 in System 3: 0.5155949998348923
# Vessel 5 assigned to Buoy 1 in System 1:
#   Energy requested: 3.214688307596458
#   Water requested: 1.8657005888603584
#   Updated energy for Buoy 1 in System 1: 1.7853116924035421
#   Updated water for Buoy 1 in System 1: 8.134299411139642
# Vessel 6 assigned to Buoy 2 in System 1:
#   Energy requested: 3.570235993959911
#   Water requested: 5.393422419156507
#   Updated energy for Buoy 2 in System 1: 1.429764006040089
#   Updated water for Buoy 2 in System 1: 4.606577580843493
# Vessel 7 assigned to Buoy 3 in System 1:
#   Energy requested: 3.22976062065625
#   Water requested: 8.960912999234932
#   Updated energy for Buoy 3 in System 1: 1.7702393793437499
#   Updated water for Buoy 3 in System 1: 1.0390870007650683
# Vessel 8 assigned to Buoy 1 in System 2:
#   Energy requested: 1.2720138998874555
#   Water requested: 1.1005192452767676
#   Updated energy for Buoy 1 in System 2: 3.7279861001125445
#   Updated water for Buoy 1 in System 2: 8.899480754723232
#
#
# Time step 19
# Vessel 1 arriving:
#   Energy requested: 0.9117406501677667
#   Water requested: 4.271077886262563
# Vessel 2 arriving:
#   Energy requested: 3.2720590636899725
#   Water requested: 8.607305832563434
# Vessel 3 arriving:
#   Energy requested: 0.027808522124762813
#   Water requested: 5.107473025775658
# Vessel 1 assigned to Buoy 2 in System 2:
#   Energy requested: 0.9117406501677667
#   Water requested: 4.271077886262563
#   Updated energy for Buoy 2 in System 2: 4.088259349832233
#   Updated water for Buoy 2 in System 2: 5.728922113737437
# Vessel 2 assigned to Buoy 3 in System 2:
#   Energy requested: 3.2720590636899725
#   Water requested: 8.607305832563434
#   Updated energy for Buoy 3 in System 2: 1.7279409363100275
#   Updated water for Buoy 3 in System 2: 1.3926941674365665
# Vessel 3 assigned to Buoy 1 in System 2:
#   Energy requested: 0.027808522124762813
#   Water requested: 5.107473025775658
#   Updated energy for Buoy 1 in System 2: 4.972191477875237
#   Updated water for Buoy 1 in System 2: 4.892526974224342
#
#
# Time step 20
# Vessel 1 arriving:
#   Energy requested: 1.669644012595116
#   Water requested: 2.2210781047073027
# Vessel 2 arriving:
#   Energy requested: 0.4794614693347312
#   Water requested: 3.3761517140362796
# Vessel 3 arriving:
#   Energy requested: 3.7716388156500766
#   Water requested: 3.2320293202075523
# Vessel 4 arriving:
#   Energy requested: 2.0751624869734644
#   Water requested: 7.030189588951778
# Vessel 5 arriving:
#   Energy requested: 1.454518409517176
#   Water requested: 9.717820827209607
# Vessel 1 assigned to Buoy 2 in System 2:
#   Energy requested: 1.669644012595116
#   Water requested: 2.2210781047073027
#   Updated energy for Buoy 2 in System 2: 3.330355987404884
#   Updated water for Buoy 2 in System 2: 7.778921895292697
# Vessel 2 assigned to Buoy 3 in System 2:
#   Energy requested: 0.4794614693347312
#   Water requested: 3.3761517140362796
#   Updated energy for Buoy 3 in System 2: 4.520538530665268
#   Updated water for Buoy 3 in System 2: 6.623848285963721
# Vessel 3 assigned to Buoy 1 in System 2:
#   Energy requested: 3.7716388156500766
#   Water requested: 3.2320293202075523
#   Updated energy for Buoy 1 in System 2: 1.2283611843499234
#   Updated water for Buoy 1 in System 2: 6.767970679792448
# Vessel 4 assigned to Buoy 2 in System 2:
#   Energy requested: 2.0751624869734644
#   Water requested: 7.030189588951778
#   Updated energy for Buoy 2 in System 2: 1.2551935004314196
#   Updated water for Buoy 2 in System 2: 0.7487323063409193
# Vessel 5 assigned to Buoy 3 in System 3:
#   Energy requested: 1.454518409517176
#   Water requested: 9.717820827209607
#   Updated energy for Buoy 3 in System 3: 3.545481590482824
#   Updated water for Buoy 3 in System 3: 0.28217917279039284
#
#
# Time step 21
# Vessel 1 arriving:
#   Energy requested: 3.849789179768445
#   Water requested: 2.5178229582536416
# Vessel 2 arriving:
#   Energy requested: 1.9889940235695418
#   Water requested: 3.0087830981676964
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 3.849789179768445
#   Water requested: 2.5178229582536416
#   Updated energy for Buoy 1 in System 3: 1.150210820231555
#   Updated water for Buoy 1 in System 3: 7.4821770417463584
# Vessel 2 assigned to Buoy 2 in System 3:
#   Energy requested: 1.9889940235695418
#   Water requested: 3.0087830981676964
#   Updated energy for Buoy 2 in System 3: 3.011005976430458
#   Updated water for Buoy 2 in System 3: 6.991216901832304
#
#
# Time step 22
# Vessel 1 arriving:
#   Energy requested: 1.1393619775098704
#   Water requested: 0.36886947354532795
# Vessel 2 arriving:
#   Energy requested: 2.4382573359195874
#   Water requested: 5.026790232288615
# Vessel 3 arriving:
#   Energy requested: 0.2059150049999574
#   Water requested: 2.7864646423661146
# Vessel 4 arriving:
#   Energy requested: 3.633063543866615
#   Water requested: 2.395618906669724
# Vessel 1 assigned to Buoy 3 in System 3:
#   Energy requested: 1.1393619775098704
#   Water requested: 0.36886947354532795
#   Updated energy for Buoy 3 in System 3: 3.8606380224901296
#   Updated water for Buoy 3 in System 3: 9.631130526454672
# Vessel 2 assigned to Buoy 1 in System 3:
#   Energy requested: 2.4382573359195874
#   Water requested: 5.026790232288615
#   Updated energy for Buoy 1 in System 3: 2.5617426640804126
#   Updated water for Buoy 1 in System 3: 4.973209767711385
# Vessel 3 assigned to Buoy 2 in System 3:
#   Energy requested: 0.2059150049999574
#   Water requested: 2.7864646423661146
#   Updated energy for Buoy 2 in System 3: 4.794084995000043
#   Updated water for Buoy 2 in System 3: 7.213535357633885
# Vessel 4 assigned to Buoy 3 in System 1:
#   Energy requested: 3.633063543866615
#   Water requested: 2.395618906669724
#   Updated energy for Buoy 3 in System 1: 1.3669364561333852
#   Updated water for Buoy 3 in System 1: 7.604381093330276
#
#
# Time step 23
# Vessel 1 arriving:
#   Energy requested: 0.5795794883648924
#   Water requested: 4.89452760277563
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 0.5795794883648924
#   Water requested: 4.89452760277563
#   Updated energy for Buoy 1 in System 1: 4.420420511635108
#   Updated water for Buoy 1 in System 1: 5.10547239722437
#
#
# Time step 24
# Vessel 1 arriving:
#   Energy requested: 3.942601816442403
#   Water requested: 2.4205527151150044
# Vessel 1 assigned to Buoy 2 in System 1:
#   Energy requested: 3.942601816442403
#   Water requested: 2.4205527151150044
#   Updated energy for Buoy 2 in System 1: 1.0573981835575972
#   Updated water for Buoy 2 in System 1: 7.579447284884996
#
#
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Cambio ascisse con valori temporali e boe già cariche

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametri globali
num_autonomous_systems = 3  # numero di sistemi di boe autonomi
n = 3  # numero di boe per ciascun sistema
cr = 4.6  # produzione costante di energia rinnovabile per timestep
kc = 0.05  # parametro di conversione energia-acqua
timesteps = 24  # durata della simulazione in ore
initial_energy = 5  # livello iniziale di energia
initial_water = 10  # livello iniziale di acqua
max_energy = 5  # energia massima accumulabile
min_energy = 0.2 * max_energy  # 20% del totale dell'energia accumulabile
max_water = 10  # acqua massima accumulabile
x2_target = 10  # livello target dell'acqua (usato nelle condizioni)
max_vessels = 9  # numero massimo di natanti che possono arrivare in ciascun timestep

# Funzione per inizializzare i vettori di stato
def initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water):
    systems = []
    for _ in range(num_autonomous_systems):
        x1 = np.zeros((n, timesteps + 1))  # energia accumulata per ciascuna boa
        x2 = np.zeros((n, timesteps + 1))  # acqua accumulata per ciascuna boa
        x1[:, 0] = initial_energy
        x2[:, 0] = initial_water
        systems.append((x1, x2))
    return systems

# Funzione per generare il numero di natanti per ciascun timestep
def generate_num_vessels_per_timestep(timesteps, max_vessels):
    num_vessels = np.zeros(timesteps, dtype=int)
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        if 5 <= k < 10:
            num_vessels[k] = np.random.randint(1, max_vessels // 3 + 1)  # Rate basso
        elif 10 <= k < 18:
            num_vessels[k] = np.random.randint(1, max_vessels + 1)  # Rate alto
        elif 18 <= k < 22:
            num_vessels[k] = np.random.randint(1, max_vessels // 2 + 1)  # Rate basso
        elif 2 <= k < 5:
            num_vessels[k] = 0  # Rate nullo
        else:
            num_vessels[k] = np.random.randint(0, 2)  # Rate quasi nullo

    return num_vessels

# Funzione per generare richieste randomiche
def generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels):
    u1 = np.zeros((max_vessels, timesteps + 1))  # energia richiesta da ciascun natante
    u2 = np.zeros((max_vessels, timesteps + 1))  # acqua richiesta da ciascun natante
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        for i in range(num_vessels[k]):
            max_possible_energy_request = max_energy - min_energy
            u1[i, k] = np.random.uniform(0, max_possible_energy_request)
            u2[i, k] = np.random.uniform(0, max_water)
    return u1, u2

# Funzione per aggiornare lo stato delle boe
def update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water):
    for i in range(n):
        if x1[i, k] / kc < (x2_target - x2[i, k]):
            # Caso 1: La batteria non ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr
            x2[i, k + 1] = x2[i, k] + (x1[i, k] / kc)
        else:
            # Caso 2: La batteria ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr - kc * (x2_target - x2[i, k])
            x2[i, k + 1] = x2_target

        # Assicura che l'energia non superi il massimo
        if x1[i, k + 1] > max_energy:
            x1[i, k + 1] = max_energy

        # Assicura che l'acqua non superi il limite massimo
        if x2[i, k + 1] > max_water:
            x2[i, k + 1] = max_water
    return x1, x2

# Funzione per assegnare le richieste dei natanti alle boe utilizzando round robin
def assign_requests_round_robin(systems, u1, u2, k, num_vessels, min_energy, max_energy, max_water, last_assigned_buoy):
    for i in range(num_vessels):
        assigned = False
        initial_system = last_assigned_buoy // n  # Inizia dal sistema dell'ultima boa assegnata
        for system_offset in range(num_autonomous_systems):
            system_index = (initial_system + system_offset) % num_autonomous_systems
            x1, x2 = systems[system_index]
            for _ in range(n):
                j = (last_assigned_buoy + 1) % n
                if (x1[j, k + 1] - u1[i, k] >= min_energy and x1[j, k + 1] - u1[i, k] <= max_energy and
                    x2[j, k + 1] - u2[i, k] >= 0 and x2[j, k + 1] - u2[i, k] <= max_water):
                    # Assegna la richiesta alla boa j del sistema system_index
                    x1[j, k + 1] -= u1[i, k]
                    x2[j, k + 1] -= u2[i, k]

                    # Assicura che l'energia non scenda sotto la soglia minima
                    if x1[j, k + 1] < min_energy:
                        x1[j, k + 1] = min_energy

                    # Assicura che l'acqua non scenda sotto 0
                    if x2[j, k + 1] < 0:
                        x2[j, k + 1] = 0

                    # Stampa le richieste e le risorse aggiornate per la boa assegnata
                    print(f"Vessel {i + 1} assigned to Buoy {j + 1} in System {system_index + 1}:")
                    print(f"  Energy requested: {u1[i, k]}")
                    print(f"  Water requested: {u2[i, k]}")
                    print(f"  Updated energy for Buoy {j + 1} in System {system_index + 1}: {x1[j, k + 1]}")
                    print(f"  Updated water for Buoy {j + 1} in System {system_index + 1}: {x2[j, k + 1]}")
                    assigned = True
                    last_assigned_buoy = j + system_index * n
                    break
            if assigned:
                break
        
        if not assigned:
            print(f"Vessel {i + 1} could not be assigned at time step {k + 1}")
    
    return last_assigned_buoy

# Funzione per eseguire la simulazione
def run_simulation_round_robin(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels):
    systems = initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water)
    num_vessels = generate_num_vessels_per_timestep(timesteps, max_vessels)
    u1, u2 = generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels)
    last_assigned_buoy = -1  # inizializza l'ultima boa assegnata

    for k in range(timesteps):
        print(f"Time step {k + 1}")
        
        for system_index, (x1, x2) in enumerate(systems):
            systems[system_index] = update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water)
        
        for i in range(num_vessels[k]):
            print(f"Vessel {i + 1} arriving:")
            print(f"  Energy requested: {u1[i, k]}")
            print(f"  Water requested: {u2[i, k]}")
        
        if num_vessels[k] > 0:
            last_assigned_buoy = assign_requests_round_robin(systems, u1, u2, k, num_vessels[k], min_energy, max_energy, max_water, last_assigned_buoy)
        print("\n")

    return systems

# Funzione per visualizzare i risultati
def plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water):
    time_labels = [f"{(6 + i) % 24:02d}:00" for i in range(timesteps + 1)]
    
    for system_index, (x1, x2) in enumerate(systems):
        print("--------------------------------------------------------------------------------------------------------------")
        plt.figure(figsize=(12, 6))
        
        for i in range(n):
            plt.subplot(2, n, i + 1)
            plt.plot(x1[i], label=f'Accumulated Energy Buoy {i+1} in System {system_index + 1}')
            plt.axhline(min_energy, color='r', linestyle='--', label='Min Energy Threshold')
            plt.axhline(max_energy, color='g', linestyle='--', label='Max Energy Threshold')
            plt.xlabel('Time')
            plt.ylabel('Energy')
            plt.xticks(ticks=range(0, timesteps + 1, 2), labels=time_labels[::2], rotation=45)
            plt.legend()
            plt.grid(True)

            plt.subplot(2, n, i + 1 + n)
            plt.plot(x2[i], label=f'Accumulated Water Buoy {i+1} in System {system_index + 1}')
            plt.axhline(max_water, color='b', linestyle='--', label='Max Water Threshold')
            plt.xlabel('Time')
            plt.ylabel('Water')
            plt.xticks(ticks=range(0, timesteps + 1, 2), labels=time_labels[::2], rotation=45)
            plt.legend()
            plt.grid(True)

        plt.tight_layout()
        plt.show()

# Esegui la simulazione con assegnazione round robin
systems = run_simulation_round_robin(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels)

# Visualizza i risultati
plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water)
# Out:
# Time step 1
#
#
# Time step 2
# Vessel 1 arriving:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 3: 3.50183952461055
#   Updated water for Buoy 1 in System 3: 0.49285693590083923
#
#
# Time step 3
#
#
# Time step 4
#
#
# Time step 5
#
#
# Time step 6
# Vessel 1 arriving:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
# Vessel 1 assigned to Buoy 2 in System 3:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 2 in System 3: 2.0720242327543796
#   Updated water for Buoy 2 in System 3: 4.013415158029634
#
#
# Time step 7
# Vessel 1 arriving:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
# Vessel 2 arriving:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
# Vessel 3 arriving:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
# Vessel 1 assigned to Buoy 3 in System 3:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 3 in System 3: 4.375925438230254
#   Updated water for Buoy 3 in System 3: 8.440054796637973
# Vessel 2 assigned to Buoy 1 in System 3:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
#   Updated energy for Buoy 1 in System 3: 4.767665551327202
#   Updated water for Buoy 1 in System 3: 1.3382385422506484
# Vessel 3 assigned to Buoy 2 in System 3:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
#   Updated energy for Buoy 2 in System 3: 2.595539953027165
#   Updated water for Buoy 2 in System 3: 2.9192742220395456
#
#
# Time step 8
# Vessel 1 arriving:
#   Energy requested: 0.08233797718320979
#   Water requested: 9.699098521619943
# Vessel 2 arriving:
#   Energy requested: 3.329770563201687
#   Water requested: 2.1233911067827616
# Vessel 3 arriving:
#   Energy requested: 0.7272998688284025
#   Water requested: 1.8340450985343382
# Vessel 1 assigned to Buoy 3 in System 3:
#   Energy requested: 0.08233797718320979
#   Water requested: 9.699098521619943
#   Updated energy for Buoy 3 in System 3: 4.91766202281679
#   Updated water for Buoy 3 in System 3: 0.300901478380057
# Vessel 2 assigned to Buoy 1 in System 3:
#   Energy requested: 3.329770563201687
#   Water requested: 2.1233911067827616
#   Updated energy for Buoy 1 in System 3: 1.670229436798313
#   Updated water for Buoy 1 in System 3: 7.876608893217238
# Vessel 3 assigned to Buoy 2 in System 3:
#   Energy requested: 0.7272998688284025
#   Water requested: 1.8340450985343382
#   Updated energy for Buoy 2 in System 3: 4.2727001311715975
#   Updated water for Buoy 2 in System 3: 8.165954901465662
#
#
# Time step 9
# Vessel 1 arriving:
#   Energy requested: 1.216968971838151
#   Water requested: 5.247564316322379
# Vessel 1 assigned to Buoy 3 in System 3:
#   Energy requested: 1.216968971838151
#   Water requested: 5.247564316322379
#   Updated energy for Buoy 3 in System 3: 3.783031028161849
#   Updated water for Buoy 3 in System 3: 4.752435683677621
#
#
# Time step 10
# Vessel 1 arriving:
#   Energy requested: 1.727780074568463
#   Water requested: 2.9122914019804194
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 1.727780074568463
#   Water requested: 2.9122914019804194
#   Updated energy for Buoy 1 in System 3: 3.272219925431537
#   Updated water for Buoy 1 in System 3: 7.087708598019581
#
#
# Time step 11
# Vessel 1 arriving:
#   Energy requested: 2.447411578889518
#   Water requested: 1.3949386065204183
# Vessel 2 arriving:
#   Energy requested: 1.1685785941408726
#   Water requested: 3.663618432936917
# Vessel 3 arriving:
#   Energy requested: 1.8242799368681437
#   Water requested: 7.851759613930136
# Vessel 4 arriving:
#   Energy requested: 0.7986951286334389
#   Water requested: 5.142344384136116
# Vessel 5 arriving:
#   Energy requested: 2.36965827544817
#   Water requested: 0.46450412719997725
# Vessel 6 arriving:
#   Energy requested: 2.4301794076057535
#   Water requested: 1.7052412368729153
# Vessel 7 arriving:
#   Energy requested: 0.26020637194111806
#   Water requested: 9.488855372533333
# Vessel 1 assigned to Buoy 2 in System 3:
#   Energy requested: 2.447411578889518
#   Water requested: 1.3949386065204183
# Vessel 5 assigned to Buoy 1 in System 2:
#   Energy requested: 2.1868411173731186
#   Water requested: 1.8485445552552704
#   Updated energy for Buoy 1 in System 2: 2.8131588826268814
#   Updated water for Buoy 1 in System 2: 8.15145544474473
# Vessel 6 assigned to Buoy 2 in System 2:
#   Energy requested: 3.8783385110582342
#   Water requested: 7.7513282336111455
#   Updated energy for Buoy 2 in System 2: 1.1216614889417658
#   Updated water for Buoy 2 in System 2: 2.2486717663888545
# Vessel 7 assigned to Buoy 3 in System 3:
#   Energy requested: 3.7579957662567565
#   Water requested: 8.948273504276488
#   Updated energy for Buoy 3 in System 3: 1.2420042337432435
#   Updated water for Buoy 3 in System 3: 1.0517264957235124
#
#
# Time step 14
# Vessel 1 arriving:
#   Energy requested: 2.3915999152443406
#   Water requested: 9.218742350231167
# Vessel 2 arriving:
#   Energy requested: 0.353970008207678
#   Water requested: 1.959828624191452
# Vessel 3 arriving:
#   Energy requested: 0.18090915564215226
#   Water requested: 3.2533033076326436
# Vessel 4 arriving:
#   Energy requested: 1.554709158757928
#   Water requested: 2.713490317738959
# Vessel 5 arriving:
#   Energy requested: 3.3149500366077174
#   Water requested: 3.567533266935893
# Vessel 6 arriving:
#   Energy requested: 1.123738038749523
#   Water requested: 5.426960831582485
# Vessel 7 arriving:
#   Energy requested: 0.5636968998990506
#   Water requested: 8.021969807540398
# Vessel 8 arriving:
#   Energy requested: 0.2982025747190833
#   Water requested: 9.868869366005173
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 2.3915999152443406
#   Water requested: 9.218742350231167
#   Updated energy for Buoy 1 in System 3: 2.6084000847556594
#   Updated water for Buoy 1 in System 3: 0.7812576497688326
# Vessel 2 assigned to Buoy 2 in System 3:
#   Energy requested: 0.353970008207678
#   Water requested: 1.959828624191452
#   Updated energy for Buoy 2 in System 3: 4.646029991792322
#   Updated water for Buoy 2 in System 3: 8.040171375808548
# Vessel 3 assigned to Buoy 3 in System 3:
#   Energy requested: 0.18090915564215226
#   Water requested: 3.2533033076326436
#   Updated energy for Buoy 3 in System 3: 4.819090844357848
#   Updated water for Buoy 3 in System 3: 6.746696692367356
# Vessel 4 assigned to Buoy 1 in System 1:
#   Energy requested: 1.554709158757928
#   Water requested: 2.713490317738959
#   Updated energy for Buoy 1 in System 1: 3.445290841242072
#   Updated water for Buoy 1 in System 1: 7.286509682261041
# Vessel 5 assigned to Buoy 2 in System 1:
#   Energy requested: 3.3149500366077174
#   Water requested: 3.567533266935893
#   Updated energy for Buoy 2 in System 1: 1.6850499633922826
#   Updated water for Buoy 2 in System 1: 6.432466733064107
# Vessel 6 assigned to Buoy 3 in System 1:
#   Energy requested: 1.123738038749523
#   Water requested: 5.426960831582485
#   Updated energy for Buoy 3 in System 1: 3.876261961250477
#   Updated water for Buoy 3 in System 1: 4.573039168417515
# Vessel 7 assigned to Buoy 1 in System 2:
#   Energy requested: 0.5636968998990506
#   Water requested: 8.021969807540398
#   Updated energy for Buoy 1 in System 2: 4.436303100100949
#   Updated water for Buoy 1 in System 2: 1.9780301924596024
# Vessel 8 assigned to Buoy 2 in System 2:
#   Energy requested: 0.2982025747190833
#   Water requested: 9.868869366005173
#   Updated energy for Buoy 2 in System 2: 4.701797425280917
#   Updated water for Buoy 2 in System 2: 0.13113063399482705
#
#
# Time step 15
# Vessel 1 arriving:
#   Energy requested: 3.0889790771866297
#   Water requested: 1.987156815341724
# Vessel 2 arriving:
#   Energy requested: 0.022088468494409597
#   Water requested: 8.154614284548341
# Vessel 3 arriving:
#   Energy requested: 2.8274293753904685
#   Water requested: 7.2900716804098735
# Vessel 4 arriving:
#   Energy requested: 3.085081386743783
#   Water requested: 0.7404465173409036
# Vessel 5 arriving:
#   Energy requested: 1.4338629141770904
#   Water requested: 1.1586905952512971
# Vessel 1 assigned to Buoy 3 in System 2:
#   Energy requested: 3.0889790771866297
#   Water requested: 1.987156815341724
#   Updated energy for Buoy 3 in System 2: 1.9110209228133703
#   Updated water for Buoy 3 in System 2: 8.012843184658276
# Vessel 2 assigned to Buoy 1 in System 2:
#   Energy requested: 0.022088468494409597
#   Water requested: 8.154614284548341
#   Updated energy for Buoy 1 in System 2: 4.97791153150559
#   Updated water for Buoy 1 in System 2: 1.845385715451659
# Vessel 3 assigned to Buoy 2 in System 2:
#   Energy requested: 2.8274293753904685
#   Water requested: 7.2900716804098735
#   Updated energy for Buoy 2 in System 2: 2.1725706246095315
#   Updated water for Buoy 2 in System 2: 2.7099283195901265
# Vessel 4 assigned to Buoy 3 in System 3:
#   Energy requested: 3.085081386743783
#   Water requested: 0.7404465173409036
#   Updated energy for Buoy 3 in System 3: 1.914918613256217
#   Updated water for Buoy 3 in System 3: 9.259553482659097
# Vessel 5 assigned to Buoy 1 in System 3:
#   Energy requested: 1.4338629141770904
#   Water requested: 1.1586905952512971
#   Updated energy for Buoy 1 in System 3: 3.5661370858229096
#   Updated water for Buoy 1 in System 3: 8.841309404748703
#
#
# Time step 16
# Vessel 1 arriving:
#   Energy requested: 3.452413703502374
#   Water requested: 6.232981268275579
# Vessel 2 arriving:
#   Energy requested: 1.3235920994105967
#   Water requested: 0.6355835028602363
# Vessel 3 arriving:
#   Energy requested: 1.2439292868626488
#   Water requested: 3.2518332202674705
# Vessel 4 arriving:
#   Energy requested: 2.9184247133522563
#   Water requested: 6.3755747135521315
# Vessel 1 assigned to Buoy 2 in System 3:
#   Energy requested: 3.452413703502374
#   Water requested: 6.232981268275579
#   Updated energy for Buoy 2 in System 3: 1.547586296497626
#   Updated water for Buoy 2 in System 3: 3.767018731724421
# Vessel 2 assigned to Buoy 3 in System 3:
#   Energy requested: 1.3235920994105967
#   Water requested: 0.6355835028602363
#   Updated energy for Buoy 3 in System 3: 3.6764079005894033
#   Updated water for Buoy 3 in System 3: 9.364416497139764
# Vessel 3 assigned to Buoy 1 in System 3:
#   Energy requested: 1.2439292868626488
#   Water requested: 3.2518332202674705
#   Updated energy for Buoy 1 in System 3: 3.756070713137351
#   Updated water for Buoy 1 in System 3: 6.7481667797325295
# Vessel 4 assigned to Buoy 2 in System 1:
#   Energy requested: 2.9184247133522563
#   Water requested: 6.3755747135521315
#   Updated energy for Buoy 2 in System 1: 2.0815752866477437
#   Updated water for Buoy 2 in System 1: 3.6244252864478685
#
#
# Time step 17
# Vessel 1 arriving:
#   Energy requested: 3.548850970305306
#   Water requested: 4.722149251619493
# Vessel 2 arriving:
#   Energy requested: 0.4783769837532068
#   Water requested: 7.13244787222995
# Vessel 3 arriving:
#   Energy requested: 3.0431401944675898
#   Water requested: 5.612771975694963
# Vessel 4 arriving:
#   Energy requested: 3.083868719818244
#   Water requested: 4.937955963643907
# Vessel 5 arriving:
#   Energy requested: 2.0909313175279762
#   Water requested: 4.275410183585496
# Vessel 6 arriving:
#   Energy requested: 0.10167650697638075
#   Water requested: 1.0789142699330445
# Vessel 7 arriving:
#   Energy requested: 0.125716742746937
#   Water requested: 6.364104112637804
# Vessel 8 arriving:
#   Energy requested: 1.2574239243053067
#   Water requested: 5.085706911647028
# Vessel 1 assigned to Buoy 3 in System 1:
#   Energy requested: 3.548850970305306
#   Water requested: 4.722149251619493
#   Updated energy for Buoy 3 in System 1: 1.4511490296946938
#   Updated water for Buoy 3 in System 1: 5.277850748380507
# Vessel 2 assigned to Buoy 1 in System 1:
#   Energy requested: 0.4783769837532068
#   Water requested: 7.13244787222995
#   Updated energy for Buoy 1 in System 1: 4.521623016246793
#   Updated water for Buoy 1 in System 1: 2.8675521277700504
# Vessel 3 assigned to Buoy 2 in System 1:
#   Energy requested: 3.0431401944675898
#   Water requested: 5.612771975694963
#   Updated energy for Buoy 2 in System 1: 1.9568598055324102
#   Updated water for Buoy 2 in System 1: 4.387228024305037
# Vessel 4 assigned to Buoy 3 in System 2:
#   Energy requested: 3.083868719818244
#   Water requested: 4.937955963643907
#   Updated energy for Buoy 3 in System 2: 1.916131280181756
#   Updated water for Buoy 3 in System 2: 5.062044036356093
# Vessel 5 assigned to Buoy 1 in System 2:
#   Energy requested: 2.0909313175279762
#   Water requested: 4.275410183585496
#   Updated energy for Buoy 1 in System 2: 2.9090686824720238
#   Updated water for Buoy 1 in System 2: 5.724589816414504
# Vessel 6 assigned to Buoy 2 in System 2:
#   Energy requested: 0.10167650697638075
#   Water requested: 1.0789142699330445
#   Updated energy for Buoy 2 in System 2: 4.89832349302362
#   Updated water for Buoy 2 in System 2: 8.921085730066956
# Vessel 7 assigned to Buoy 3 in System 3:
#   Energy requested: 0.125716742746937
#   Water requested: 6.364104112637804
#   Updated energy for Buoy 3 in System 3: 4.874283257253063
#   Updated water for Buoy 3 in System 3: 3.635895887362196
# Vessel 8 assigned to Buoy 1 in System 3:
#   Energy requested: 1.2574239243053067
#   Water requested: 5.085706911647028
#   Updated energy for Buoy 1 in System 3: 3.7425760756946933
#   Updated water for Buoy 1 in System 3: 4.914293088352972
#
#
# Time step 18
# Vessel 1 arriving:
#   Energy requested: 3.630265895704372
#   Water requested: 2.4929222914887497

#   Energy requested: 3.7716388156500766
#   Water requested: 3.2320293202075523
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 0.4794614693347312
#   Water requested: 3.3761517140362796
#   Updated energy for Buoy 1 in System 2: 4.520538530665268
#   Updated water for Buoy 1 in System 2: 6.623848285963721
# Vessel 2 assigned to Buoy 2 in System 2:
#   Energy requested: 3.7716388156500766
#   Water requested: 3.2320293202075523
#   Updated energy for Buoy 2 in System 2: 1.2283611843499234
#   Updated water for Buoy 2 in System 2: 6.767970679792448
#
#
# Time step 23
# Vessel 1 arriving:
#   Energy requested: 2.0751624869734644
#   Water requested: 7.030189588951778
# Vessel 1 assigned to Buoy 3 in System 2:
#   Energy requested: 2.0751624869734644
#   Water requested: 7.030189588951778
#   Updated energy for Buoy 3 in System 2: 2.9248375130265356
#   Updated water for Buoy 3 in System 2: 2.969810411048222
#
#
# Time step 24
# Vessel 1 arriving:
#   Energy requested: 1.454518409517176
#   Water requested: 9.717820827209607
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 1.454518409517176
#   Water requested: 9.717820827209607
#   Updated energy for Buoy 1 in System 2: 3.545481590482824
#   Updated water for Buoy 1 in System 2: 0.28217917279039284
#
#
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # VERSIONE CON ASSEGNAZIONE GENERALI BIZANTINI

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linprog
from collections import Counter

# Parametri globali
num_autonomous_systems = 3  # numero di sistemi di boe autonomi
n = 3  # numero di boe per ciascun sistema
cr = 4.6  # produzione costante di energia rinnovabile per timestep
kc = 0.05  # parametro di conversione energia-acqua
timesteps = 24  # durata della simulazione in ore
initial_energy = 5  # livello iniziale di energia
initial_water = 10  # livello iniziale di acqua
max_energy = 5  # energia massima accumulabile
min_energy = 0.2 * max_energy  # 20% del totale dell'energia accumulabile
max_water = 10  # acqua massima accumulabile
x2_target = 10  # livello target dell'acqua (usato nelle condizioni)
max_vessels = 9  # numero massimo di natanti che possono arrivare in ciascun timestep

# Funzione per inizializzare i vettori di stato
def initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water):
    systems = []
    for _ in range(num_autonomous_systems):
        x1 = np.zeros((n, timesteps + 1))  # energia accumulata per ciascuna boa
        x2 = np.zeros((n, timesteps + 1))  # acqua accumulata per ciascuna boa
        x1[:, 0] = initial_energy
        x2[:, 0] = initial_water
        systems.append((x1, x2))
    return systems

# Funzione per generare il numero di natanti per ciascun timestep
def generate_num_vessels_per_timestep(timesteps, max_vessels):
    num_vessels = np.zeros(timesteps, dtype=int)
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        if 5 <= k < 10:
            num_vessels[k] = np.random.randint(1, max_vessels // 3 + 1)  # Rate basso
        elif 10 <= k < 18:
            num_vessels[k] = np.random.randint(1, max_vessels + 1)  # Rate alto
        elif 18 <= k < 22:
            num_vessels[k] = np.random.randint(1, max_vessels // 2 + 1)  # Rate basso
        elif 2 <= k < 5:
            num_vessels[k] = 0  # Rate nullo
        else:
            num_vessels[k] = np.random.randint(0, 2)  # Rate quasi nullo

    return num_vessels

# Funzione per generare richieste randomiche
def generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels):
    u1 = np.zeros((max_vessels, timesteps + 1))  # energia richiesta da ciascun natante
    u2 = np.zeros((max_vessels, timesteps + 1))  # acqua richiesta da ciascun natante
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        for i in range(num_vessels[k]):
            max_possible_energy_request = max_energy - min_energy
            u1[i, k] = np.random.uniform(0, max_possible_energy_request)
            u2[i, k] = np.random.uniform(0, max_water)
    return u1, u2

# Funzione per aggiornare lo stato delle boe
def update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water):
    for i in range(n):
        if x1[i, k] / kc < (x2_target - x2[i, k]):
            # Caso 1: La batteria non ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr
            x2[i, k + 1] = x2[i, k] + (x1[i, k] / kc)
        else:
            # Caso 2: La batteria ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr - kc * (x2_target - x2[i, k])
            x2[i, k + 1] = x2_target

        # Assicura che l'energia non superi il massimo
        if x1[i, k + 1] > max_energy:
            x1[i, k + 1] = max_energy

        # Assicura che l'acqua non superi il limite massimo
        if x2[i, k + 1] > max_water:
            x2[i, k + 1] = max_water
    return x1, x2

# Funzione per assegnare le richieste dei natanti ai sistemi di boe usando un algoritmo greedy ottimizzato
def assign_requests_optimized(system, system_index, u1, u2, k, num_vessels, min_energy, max_energy, max_water):
    x1, x2 = system
    for i in range(num_vessels):
        best_buoy = None
        min_impact = float('inf')

        for j in range(n):
            if (x1[j, k + 1] - u1[i, k] >= min_energy and x2[j, k + 1] - u2[i, k] >= 0):
                impact = (x1[j, k + 1] - u1[i, k]) + (x2[j, k + 1] - u2[i, k])
                if impact < min_impact:
                    min_impact = impact
                    best_buoy = j

        if best_buoy is not None:
            x1[best_buoy, k + 1] -= u1[i, k]
            x2[best_buoy, k + 1] -= u2[i, k]

            if x1[best_buoy, k + 1] < min_energy:
                x1[best_buoy, k + 1] = min_energy
            if x2[best_buoy, k + 1] < 0:
                x2[best_buoy, k + 1] = 0

            print(f"Vessel {i + 1} assigned to Buoy {best_buoy + 1} in System {system_index + 1}:")
            print(f"  Energy requested: {u1[i, k]}")
            print(f"  Water requested: {u2[i, k]}")
            print(f"  Updated energy for Buoy {best_buoy + 1} in System {system_index + 1}: {x1[best_buoy, k + 1]}")
            print(f"  Updated water for Buoy {best_buoy + 1} in System {system_index + 1}: {x2[best_buoy, k + 1]}")
        else:
            print(f"Vessel {i + 1} could not be assigned at time step {k + 1}")

# Funzione per condividere e verificare i dati tra le boe
def verify_and_consensus(systems, k):
    for system in systems:
        x1, x2 = system

        # Raccolta dei dati
        energy_reports = np.zeros((n, n))
        water_reports = np.zeros((n, n))
        for i in range(n):
            for j in range(n):
                energy_reports[i, j] = x1[j, k + 1]
                water_reports[i, j] = x2[j, k + 1]

        # Verifica dei dati
        verified_energy = np.zeros(n)
        verified_water = np.zeros(n)
        for i in range(n):
            energy_counts = Counter(energy_reports[i, :])
            water_counts = Counter(water_reports[i, :])
            verified_energy[i] = energy_counts.most_common(1)[0][0]
            verified_water[i] = water_counts.most_common(1)[0][0]

        # Aggiornamento dei dati verificati
        for i in range(n):
            x1[i, k + 1] = verified_energy[i]
            x2[i, k + 1] = verified_water[i]

# Funzione per eseguire la simulazione
def run_simulation_optimized(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels):
    systems = initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water)
    num_vessels = generate_num_vessels_per_timestep(timesteps, max_vessels)
    u1, u2 = generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels)

    for k in range(timesteps):
        print(f"Time step {k + 1}")

        for system_index, (x1, x2) in enumerate(systems):
            systems[system_index] = update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water)
        verify_and_consensus(systems, k)
        for system_index, system in enumerate(systems):
            if num_vessels[k] > 0:
                print(f"Assigning requests for system {system_index + 1}")
                assign_requests_optimized(system, system_index, u1, u2, k, num_vessels[k], min_energy, max_energy, max_water)
        print("\n")

    return systems

# Funzione per visualizzare i risultati
def plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water):
    for system_index, (x1, x2) in enumerate(systems):
        print("--------------------------------------------------------------------------------------------------------------")
        plt.figure(figsize=(12, 6))
        
        for i in range(n):
            plt.subplot(2, n, i + 1)
            plt.plot(x1[i], label=f'Accumulated Energy Buoy {i+1} in System {system_index + 1}')
            plt.axhline(min_energy, color='r', linestyle='--', label='Min Energy Threshold')
            plt.axhline(max_energy, color='g', linestyle='--', label='Max Energy Threshold')
            plt.xlabel('Time step')
            plt.ylabel('Energy')
            plt.legend()
            plt.grid(True)

            plt.subplot(2, n, i + 1 + n)
            plt.plot(x2[i], label=f'Accumulated Water Buoy {i+1} in System {system_index + 1}')
            plt.axhline(max_water, color='b', linestyle='--', label='Max Water Threshold')
            plt.xlabel('Time step')
            plt.ylabel('Water')
            plt.legend()
            plt.grid(True)

        plt.tight_layout()
        plt.show()

# Esegui la simulazione con più sistemi di boe
systems = run_simulation_optimized(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels)

# Visualizza i risultati
plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water)
# Out:
# Time step 1
#
#
# Time step 2
# Assigning requests for system 1
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 1: 3.50183952461055
#   Updated water for Buoy 1 in System 1: 0.49285693590083923
# Assigning requests for system 2
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 2: 3.50183952461055
#   Updated water for Buoy 1 in System 2: 0.49285693590083923
# Assigning requests for system 3
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 3: 3.50183952461055
#   Updated water for Buoy 1 in System 3: 0.49285693590083923
#
#
# Time step 3
#
#
# Time step 4
#
#
# Time step 5
#
#
# Time step 6
# Assigning requests for system 1
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 1 in System 1: 2.0720242327543796
#   Updated water for Buoy 1 in System 1: 4.013415158029634
# Assigning requests for system 2
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 1 in System 2: 2.0720242327543796
#   Updated water for Buoy 1 in System 2: 4.013415158029634
# Assigning requests for system 3
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 1 in System 3: 2.0720242327543796
#   Updated water for Buoy 1 in System 3: 4.013415158029634
#
#
# Time step 7
# Assigning requests for system 1
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 1 in System 1: 4.375925438230254
#   Updated water for Buoy 1 in System 1: 8.440054796637973
# Vessel 2 assigned to Buoy 2 in System 1:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
#   Updated energy for Buoy 2 in System 1: 4.767665551327202
#   Updated water for Buoy 2 in System 1: 1.3382385422506484
# Vessel 3 assigned to Buoy 1 in System 1:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
#   Updated energy for Buoy 1 in System 1: 1.9714653912574192
#   Updated water for Buoy 1 in System 1: 1.3593290186775189
# Assigning requests for system 2
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 1 in System 2: 4.375925438230254
#   Updated water for Buoy 1 in System 2: 8.440054796637973
# Vessel 2 assigned to Buoy 2 in System 2:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
#   Updated energy for Buoy 2 in System 2: 4.767665551327202
#   Updated water for Buoy 2 in System 2: 1.3382385422506484
# Vessel 3 assigned to Buoy 1 in System 2:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
#   Updated energy for Buoy 1 in System 2: 1.9714653912574192
#   Updated water for Buoy 1 in System 2: 1.3593290186775189
# Assigning requests for system 3
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 1 in System 3: 4.375925438230254
#   Updated water for Buoy 1 in System 3: 8.440054796637973
# Vessel 2 assigned to Buoy 2 in System 3:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
#   Updated energy for Buoy 2 in System 3: 4.767665551327202
#   Updated water for Buoy 2 in System 3: 1.3382385422506484
# Vessel 3 assigned to Buoy 1 in System 3:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
#   Updated energy for Buoy 1 in System 3: 1.9714653912574192
#   Updated water for Buoy 1 in System 3: 1.3593290186775189
#
#
# Time step 8
# Assigning requests for system 1
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 0.08233797718320979
#   Water requested: 9.699098521619943
#   Updated energy for Buoy 1 in System 1: 4.91766202281679
#   Updated water for Buoy 1 in System 1: 0.300901478380057
# Vessel 2 assigned to Buoy 2 in System 1:
#   Energy requested: 3.329770563201687
#   Water requested: 2.1233911067827616
# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import linprog
from collections import Counter

# Parametri globali
num_autonomous_systems = 3  # numero di sistemi di boe autonomi
n = 3  # numero di boe per ciascun sistema
cr = 4.6  # produzione costante di energia rinnovabile per timestep
kc = 0.05  # parametro di conversione energia-acqua
timesteps = 24  # durata della simulazione in ore
initial_energy = 1  # livello iniziale di energia
initial_water = 0  # livello iniziale di acqua
max_energy = 5  # energia massima accumulabile
min_energy = 0.2 * max_energy  # 20% del totale dell'energia accumulabile
max_water = 10  # acqua massima accumulabile
x2_target = 10  # livello target dell'acqua (usato nelle condizioni)
max_vessels = 9  # numero massimo di natanti che possono arrivare in ciascun timestep

# Funzione per inizializzare i vettori di stato
def initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water):
    systems = []
    for _ in range(num_autonomous_systems):
        x1 = np.zeros((n, timesteps + 1))  # energia accumulata per ciascuna boa
        x2 = np.zeros((n, timesteps + 1))  # acqua accumulata per ciascuna boa
        x1[:, 0] = initial_energy
        x2[:, 0] = initial_water
        systems.append((x1, x2))
    return systems

# Funzione per generare il numero di natanti per ciascun timestep
def generate_num_vessels_per_timestep(timesteps, max_vessels):
    num_vessels = np.zeros(timesteps, dtype=int)
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        if 5 <= k < 10:
            num_vessels[k] = np.random.randint(1, max_vessels // 3 + 1)  # Rate basso
        elif 10 <= k < 18:
            num_vessels[k] = np.random.randint(1, max_vessels + 1)  # Rate alto
        elif 18 <= k < 22:
            num_vessels[k] = np.random.randint(1, max_vessels // 2 + 1)  # Rate basso
        elif 2 <= k < 5:
            num_vessels[k] = 0  # Rate nullo
        else:
            num_vessels[k] = np.random.randint(0, 2)  # Rate quasi nullo

    return num_vessels

# Funzione per generare richieste randomiche
def generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels):
    u1 = np.zeros((max_vessels, timesteps + 1))  # energia richiesta da ciascun natante
    u2 = np.zeros((max_vessels, timesteps + 1))  # acqua richiesta da ciascun natante
    np.random.seed(42)  # per riproducibilità

    for k in range(timesteps):
        for i in range(num_vessels[k]):
            max_possible_energy_request = max_energy - min_energy
            u1[i, k] = np.random.uniform(0, max_possible_energy_request)
            u2[i, k] = np.random.uniform(0, max_water)
    return u1, u2

# Funzione per aggiornare lo stato delle boe
def update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water):
    for i in range(n):
        if x1[i, k] / kc < (x2_target - x2[i, k]):
            # Caso 1: La batteria non ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr
            x2[i, k + 1] = x2[i, k] + (x1[i, k] / kc)
        else:
            # Caso 2: La batteria ricarica completamente il serbatoio
            x1[i, k + 1] = x1[i, k] + cr - kc * (x2_target - x2[i, k])
            x2[i, k + 1] = x2_target

        # Assicura che l'energia non superi il massimo
        if x1[i, k + 1] > max_energy:
            x1[i, k + 1] = max_energy

        # Assicura che l'acqua non superi il limite massimo
        if x2[i, k + 1] > max_water:
            x2[i, k + 1] = max_water
    return x1, x2

# Funzione per assegnare le richieste dei natanti ai sistemi di boe usando un algoritmo greedy ottimizzato
def assign_requests_optimized(system, system_index, u1, u2, k, num_vessels, min_energy, max_energy, max_water):
    x1, x2 = system
    for i in range(num_vessels):
        best_buoy = None
        min_impact = float('inf')

        for j in range(n):
            if (x1[j, k + 1] - u1[i, k] >= min_energy and x2[j, k + 1] - u2[i, k] >= 0):
                impact = (x1[j, k + 1] - u1[i, k]) + (x2[j, k + 1] - u2[i, k])
                if impact < min_impact:
                    min_impact = impact
                    best_buoy = j

        if best_buoy is not None:
            x1[best_buoy, k + 1] -= u1[i, k]
            x2[best_buoy, k + 1] -= u2[i, k]

            if x1[best_buoy, k + 1] < min_energy:
                x1[best_buoy, k + 1] = min_energy
            if x2[best_buoy, k + 1] < 0:
                x2[best_buoy, k + 1] = 0

            print(f"Vessel {i + 1} assigned to Buoy {best_buoy + 1} in System {system_index + 1}:")
            print(f"  Energy requested: {u1[i, k]}")
            print(f"  Water requested: {u2[i, k]}")
            print(f"  Updated energy for Buoy {best_buoy + 1} in System {system_index + 1}: {x1[best_buoy, k + 1]}")
            print(f"  Updated water for Buoy {best_buoy + 1} in System {system_index + 1}: {x2[best_buoy, k + 1]}")
        else:
            print(f"Vessel {i + 1} could not be assigned at time step {k + 1}")

# Funzione per condividere e verificare i dati tra le boe
def verify_and_consensus(systems, k):
    for system in systems:
        x1, x2 = system

        # Raccolta dei dati
        energy_reports = np.zeros((n, n))
        water_reports = np.zeros((n, n))
        for i in range(n):
            for j in range(n):
                energy_reports[i, j] = x1[j, k + 1]
                water_reports[i, j] = x2[j, k + 1]

        # Verifica dei dati
        verified_energy = np.zeros(n)
        verified_water = np.zeros(n)
        for i in range(n):
            energy_counts = Counter(energy_reports[i, :])
            water_counts = Counter(water_reports[i, :])
            verified_energy[i] = energy_counts.most_common(1)[0][0]
            verified_water[i] = water_counts.most_common(1)[0][0]

        # Aggiornamento dei dati verificati
        for i in range(n):
            x1[i, k + 1] = verified_energy[i]
            x2[i, k + 1] = verified_water[i]

# Funzione per eseguire la simulazione
def run_simulation_optimized(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels):
    systems = initialize_state_vectors(num_autonomous_systems, n, timesteps, initial_energy, initial_water)
    num_vessels = generate_num_vessels_per_timestep(timesteps, max_vessels)
    u1, u2 = generate_random_requests(timesteps, max_vessels, max_energy, min_energy, max_water, num_vessels)

    for k in range(timesteps):
        print(f"Time step {k + 1}")

        for system_index, (x1, x2) in enumerate(systems):
            systems[system_index] = update_buoys(x1, x2, k, cr, kc, x2_target, max_energy, max_water)
        verify_and_consensus(systems, k)
        for system_index, system in enumerate(systems):
            if num_vessels[k] > 0:
                print(f"Assigning requests for system {system_index + 1}")
                assign_requests_optimized(system, system_index, u1, u2, k, num_vessels[k], min_energy, max_energy, max_water)
        print("\n")

    return systems

# Funzione per visualizzare i risultati
def plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water):
    time_labels = [f"{(6 + i) % 24:02d}:00" for i in range(timesteps + 1)]
    for system_index, (x1, x2) in enumerate(systems):
        print("--------------------------------------------------------------------------------------------------------------")
        plt.figure(figsize=(12, 6))
        
        for i in range(n):
            plt.subplot(2, n, i + 1)
            plt.plot(x1[i], label=f'Accumulated Energy Buoy {i+1} in System {system_index + 1}')
            plt.axhline(min_energy, color='r', linestyle='--', label='Min Energy Threshold')
            plt.axhline(max_energy, color='g', linestyle='--', label='Max Energy Threshold')
            plt.xlabel('Time')
            plt.ylabel('Energy')
            plt.xticks(ticks=range(0, timesteps + 1, 2), labels=time_labels[::2], rotation=45)
            plt.legend()
            plt.grid(True)

            plt.subplot(2, n, i + 1 + n)
            plt.plot(x2[i], label=f'Accumulated Water Buoy {i+1} in System {system_index + 1}')
            plt.axhline(max_water, color='b', linestyle='--', label='Max Water Threshold')
            plt.xlabel('Time')
            plt.ylabel('Water')
            plt.xticks(ticks=range(0, timesteps + 1, 2), labels=time_labels[::2], rotation=45)
            plt.legend()
            plt.grid(True)

        plt.tight_layout()
        plt.show()

# Esegui la simulazione con più sistemi di boe
systems = run_simulation_optimized(num_autonomous_systems, n, timesteps, cr, kc, x2_target, max_energy, min_energy, max_water, max_vessels)

# Visualizza i risultati
plot_results_multiple_systems(systems, n, timesteps, min_energy, max_energy, max_water)
# Out:
# Time step 1
#
#
# Time step 2
# Assigning requests for system 1
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 1: 3.50183952461055
#   Updated water for Buoy 1 in System 1: 0.49285693590083923
# Assigning requests for system 2
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 2: 3.50183952461055
#   Updated water for Buoy 1 in System 2: 0.49285693590083923
# Assigning requests for system 3
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 1.49816047538945
#   Water requested: 9.50714306409916
#   Updated energy for Buoy 1 in System 3: 3.50183952461055
#   Updated water for Buoy 1 in System 3: 0.49285693590083923
#
#
# Time step 3
#
#
# Time step 4
#
#
# Time step 5
#
#
# Time step 6
# Assigning requests for system 1
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 1 in System 1: 2.0720242327543796
#   Updated water for Buoy 1 in System 1: 4.013415158029634
# Assigning requests for system 2
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 1 in System 2: 2.0720242327543796
#   Updated water for Buoy 1 in System 2: 4.013415158029634
# Assigning requests for system 3
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 2.9279757672456204
#   Water requested: 5.986584841970366
#   Updated energy for Buoy 1 in System 3: 2.0720242327543796
#   Updated water for Buoy 1 in System 3: 4.013415158029634
#
#
# Time step 7
# Assigning requests for system 1
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 1 in System 1: 4.375925438230254
#   Updated water for Buoy 1 in System 1: 8.440054796637973
# Vessel 2 assigned to Buoy 2 in System 1:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
#   Updated energy for Buoy 2 in System 1: 4.767665551327202
#   Updated water for Buoy 2 in System 1: 1.3382385422506484
# Vessel 3 assigned to Buoy 1 in System 1:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
#   Updated energy for Buoy 1 in System 1: 1.9714653912574192
#   Updated water for Buoy 1 in System 1: 1.3593290186775189
# Assigning requests for system 2
# Vessel 1 assigned to Buoy 1 in System 2:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 1 in System 2: 4.375925438230254
#   Updated water for Buoy 1 in System 2: 8.440054796637973
# Vessel 2 assigned to Buoy 2 in System 2:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
#   Updated energy for Buoy 2 in System 2: 4.767665551327202
#   Updated water for Buoy 2 in System 2: 1.3382385422506484
# Vessel 3 assigned to Buoy 1 in System 2:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
#   Updated energy for Buoy 1 in System 2: 1.9714653912574192
#   Updated water for Buoy 1 in System 2: 1.3593290186775189
# Assigning requests for system 3
# Vessel 1 assigned to Buoy 1 in System 3:
#   Energy requested: 0.6240745617697461
#   Water requested: 1.5599452033620265
#   Updated energy for Buoy 1 in System 3: 4.375925438230254
#   Updated water for Buoy 1 in System 3: 8.440054796637973
# Vessel 2 assigned to Buoy 2 in System 3:
#   Energy requested: 0.23233444867279784
#   Water requested: 8.661761457749352
#   Updated energy for Buoy 2 in System 3: 4.767665551327202
#   Updated water for Buoy 2 in System 3: 1.3382385422506484
# Vessel 3 assigned to Buoy 1 in System 3:
#   Energy requested: 2.404460046972835
#   Water requested: 7.080725777960454
#   Updated energy for Buoy 1 in System 3: 1.9714653912574192
#   Updated water for Buoy 1 in System 3: 1.3593290186775189
#
#
# Time step 8
# Assigning requests for system 1
# Vessel 1 assigned to Buoy 1 in System 1:
#   Energy requested: 0.08233797718320979
#   Water requested: 9.699098521619943
#   Updated energy for Buoy 1 in System 1: 4.91766202281679
#   Updated water for Buoy 1 in System 1: 0.300901478380057
# Vessel 2 assigned to Buoy 2 in System 1:
#   Energy requested: 3.329770563201687
#   Water requested: 2.1233911067827616