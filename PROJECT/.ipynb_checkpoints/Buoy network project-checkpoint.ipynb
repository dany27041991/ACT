# %% [markdown]
# ## Description of the problem
#
# The problem concerns a network of buoys that produce electricity from renewable sources and use this energy for water desalination. Furthermore, vessels (such as boats) can go to a buoy to stock up on desalinated water and energy. The goal is to efficiently manage the production and use of resources.
#
# ## Detail of the Model
# ### Production and Desalination System
#
# Each buoy is equipped with:
# * Energy production system: produces electricity from renewable sources, indicated as $c_r$
# * Battery: stores the energy produced with a discharge efficiency $r_s$
# * Desalination system: Transforms energy into desalinated water with an efficiency $r_d$.
#
# ## Dynamic Equations
#
# The dynamic equations describe the evolution of the accumulated energy and desalinated water over time.

# %% [markdown]
# ### First case for each boy
# $$
#     \begin{cases}
#       x_1(k+1)=c_r\\
#       x_2(k+1)=x_2(k)+\frac{x_1(k)}{k_c}
#     \end{cases}\
# $$
#
# $$
#     x(k+1)=
#     \begin{bmatrix}
#     0 & 0 \\
#     \frac{1}{k_c} & 1
#     \end{bmatrix}
#     \begin{bmatrix}
#     x_1 \\
#     x_2
#     \end{bmatrix}
#     +
#     \begin{bmatrix}
#     c_r \\
#     0
#     \end{bmatrix}
# $$
#
# Where:
# * $x_1$ represents the accumulated energy.
# * $x_2$ represents accumulated water.
# * $c_r$ is the constant amount of renewable energy available.
# * $k_c$ is an energy to water conversion parameter.

# %% [markdown]
# ## Second case for each boy
# $$
#     \begin{cases}
#       x_1(k+1)=x_1(k)-k_cx_2(k)+(c_r+k_cx_2^t)\\
#       x_2(k+1)=x_2^t
#     \end{cases}\
# $$
#
# $$
#     x(k+1)=
#     \begin{bmatrix}
#     1 & -k_c \\
#     0 & 0
#     \end{bmatrix}
#     x(k)
#     +
#     \begin{bmatrix}
#     c_r+k_cx_2^t \\
#     x_2^t
#     \end{bmatrix}
# $$

# %% [markdown]
# ## Complete case
# $$
# \begin{bmatrix}
# \begin{bmatrix}
# x_1^1 \\
# x_2^1
# \end{bmatrix} \\
# .\\.\\.\\.\\
# \begin{bmatrix}
# x_1^n \\
# x_2^n
# \end{bmatrix}
# \end{bmatrix}
# =
# \begin{bmatrix}
# \begin{bmatrix}
# [A_{sc}^1 \text{ or } A_{si}^1] & . \\
# . & [A_{sc}^2 \text{ or } A_{si}^2] & . \\
# . & . & . \\
# . & . & . \\
# . & . & . \\
# . & . & . \\
# . & . & . \\
# \end{bmatrix}
# \end{bmatrix}
# \begin{bmatrix}
# \begin{bmatrix}
# x_1^1(k) \\
# x_2^1(k)
# \end{bmatrix} \\
# .\\.\\.\\.\\.
# \begin{bmatrix}
# x_1^n(k) \\
# x_2^n(k)
# \end{bmatrix}
# \end{bmatrix}
# +
# \begin{bmatrix}
# \begin{bmatrix}
# 1 & 0 \\
# 0 & 1
# \end{bmatrix} \\
# \begin{bmatrix}
# 0 & 0 \\
# 0 & 0
# \end{bmatrix} \\
# .\\.\\.\\.
# \end{bmatrix}
# \begin{bmatrix}
# u_1 \\
# u_2
# \end{bmatrix}
# $$
#
# * $A_{sc}$: Represents complete discharge, i.e. the situation in which all available energy is used or withdrawn.
# * $A_{si}$: Represents incomplete discharge, i.e. the situation in which only a part of the available energy is used or withdrawn.
#
# ### Ratio between Complete and Incomplete Discharge_QUESTA PARTE CI POSSIAMO PENSARE, MA DERIVA DA UN MIO ERRORE DI SCRITTURA
# The ratio $\frac{A_{sc}^1}{A_{si}^1}$ for the 1st mark can be interpreted as a measure of efficiency or the effectiveness with which energy and water are used compared to ideal conditions (full discharge).
#
# ### Interpretation of the Report
#
# 1. System Efficiency:
#     * A larger value of the $$\frac{A_{sc}^1}{A_{si}^1}$$ ratio indicates that the buoy is more efficient at using available energy than an incomplete discharge.
#     * A lower value may indicate inefficiencies or losses in the system.
#
# 2. Resource Management:
#     * The ratio helps determine how well resources are being used compared to an ideal situation.
#     * It can be used to optimize resource management, balancing between complete and incomplete discharges as needed.
#
# ### Practical Example
#
# Suppose that:
#
# * $A_{sc}^1$ is a matrix or factor representing the amount of energy completely discharged by the first buoy.
# * $A_{si}^1$ represents the amount of energy incompletely discharged.
#
# If $A_{sc}^1$=100 energy units and $A_{si}^1$=50 energy units, the ratio would be $\frac{100}{50}$=2. This ratio can be used to evaluate the buoy's performance relative to ideal energy use.
#
# The $\frac{A_{sc}^1}{A_{si}^1}$ ratio indicates the relative efficiency of complete discharge versus incomplete discharge for the 1st buoy. This concept is crucial to optimize resource management in the buoy network, allowing real behavior to be compared with ideal behavior and improving operational strategies.

# %% [markdown]
# ### Hypothesis:
# * Do priorità alla produzione di acqua
# * voglio arrivare ad $x_1^{target}$ ed $x_2^{target}$
#
# ## Case 1
# La batteria non permette di ricaricare tutto il tank
#
# $$
# \frac{x_1}{k_c}<(x_2^t-x_2))
# $$
#
# where the first term of the inequality indicates the maximum reproducible quantity of water and the second the quantity of water required to reach the target.
#
# $$
#     \begin{cases}
#       x_1(k+1)=x_1(k)+c_r-\frac{k_cx_1(k)}{k_c}\\
#       x_2(k+1)=x_2(k)+\frac{x_1(k)}{k_c}
#     \end{cases}\
# $$
#
# the result is:
#
# $$
#     \begin{cases}
#       x_1=c_r\\
#       x_2<x_2^t
#     \end{cases}\
# $$

# %% [markdown]
# ## Case 2
# I charge the entire tank thanks to the battery
#
# $$
# \frac{x_1}{k_c}>(x_2^t-x_2))
# $$
#
# $$
#     \begin{cases}
#       x_1(k+1)=x_1(k)+c_r-k_c(x_2^t-x_2(k))\\
#       x_2(k+1)=x_2(k)+(x_2^t-x_2(k))
#     \end{cases}\
# $$
#
# the result is:
#
# $$
#     \begin{cases}
#       x_1\ne0\\
#       x_2=x_2^t
#     \end{cases}\
# $$

# %% [markdown]
# ## Energy flow
# ![SNOWFALL](./images/energetic-flow.png)
#
# The energy flow diagram shows the transformation of renewable energy into water through the battery and desalination process:
#
# 1. Renewable energy $c_r$.
# 2. Battery with discharge efficiency $r_s$.
# 3. Desalination with efficiency $r_d$.
# 4. Water accumulation in the tank.
#
# Where the conversion is given by:
# $$
# \frac{1}{k_c}
# $$

# %% [markdown]
# ### Considerations for Vessels
#
# Vessels that go to the buoys to stock up on water and energy must be integrated into the model. You can think of adding variables that represent the quantity of resources taken from the boats:
# * $u_1$: Energy withdrawn.
# * $u_2$: Water taken.
#
# The full model could then include these withdrawals in the dynamic equations:
# $$
# \begin{cases}
# x_1(k + 1) = c_r - u_1 \\
# x_2(k + 1) = x_2(k) + \frac{x_1(k)}{k_s} - u_2
# \end{cases}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definizione dei parametri
cr = 1.0  # Costante di produzione di energia da fonti rinnovabili per ogni boa
kc = 1.0  # Parametro di conversione energia-acqua
n = 3   # Numero di boe
max_energy = 10.0  # Energia massima accumulata per ciascuna boa
max_water = 10.0   # Acqua massima accumulata per ciascuna boa

# Funzione per il primo caso per una singola boa
def first_case(x, cr, kc, max_energy, max_water):
    x1, x2 = x
    x1_next = min(x1 + cr, max_energy)  # Limita l'energia al massimo consentito
    x2_next = min(x2 + x1 / kc, max_water)  # Limita l'acqua al massimo consentito
    return np.array([x1_next, x2_next])

# Funzione per il secondo caso per una singola boa
def second_case(x, cr, kc, max_energy, max_water):
    x1, x2 = x
    x1_next = min(x1 - kc * x2 + (cr + kc * x2), max_energy)  # Limita l'energia al massimo consentito
    x2_next = min(x2, max_water)  # Limita l'acqua al massimo consentito
    return np.array([x1_next, x2_next])

# Funzione per considerazioni per le navi
def vessel_considerations(x, cr, kc, u1, u2, max_energy, max_water):
    x1, x2 = x
    # Calcolare la nuova energia e acqua dopo aver sottratto l'uso richiesto
    energia_residua = max(x1 - u1, 0)
    acqua_residua = max(x2 - u2, 0)
    
    # Produzione di acqua con energia residua, limitata a 1 unità di acqua per istante
    acqua_prodotta = min(energia_residua / kc, max_water - acqua_residua, 1)
    
    # Calcola quanta energia è stata utilizzata per produrre l'acqua
    energia_usata_per_acqua = acqua_prodotta * kc
    
    # Aggiornamento dello stato della boa
    energia_residua = max(energia_residua - energia_usata_per_acqua, 0)
    
    # Produzione di energia dai pannelli solari e moto ondoso
    energia_residua = min(energia_residua + cr, max_energy)
    acqua_residua = min(acqua_residua + acqua_prodotta, max_water)
    
    return np.array([energia_residua, acqua_residua])

# Funzione per determinare la condizione del primo caso
def condition_for_first_case(x, kc):
    x1, x2 = x
    return x1 / kc < (x2 + 1 - x2)

# Funzione per selezionare la boa con risorse sufficienti e massime disponibili
def select_best_buoy(n, x_next, u1, u2):
    best_buoy = -1
    max_resources = -1
    for i in range(n):
        x_i = x_next[i*2:(i+1)*2]
        if x_i[0] >= u1 and x_i[1] >= u2:
            available_resources = x_i[0] + x_i[1]
            if available_resources > max_resources:
                max_resources = available_resources
                best_buoy = i
    return best_buoy

# Funzione per gestire n boe e assegnare risorse alle navi
def multiple_buoys_with_vessels(n, x, cr, kc, vessel_request, max_energy, max_water):
    x_next = np.zeros_like(x)
    for i in range(n):
        x_i = x[i*2:(i+1)*2]
        # Aggiorna l'energia e l'acqua per ogni boa
        energia_residua = min(x_i[0] + cr, max_energy)
        acqua_residua = min(x_i[1] + min(energia_residua, 1), max_water)
        x_next[i*2:(i+1)*2] = np.array([energia_residua, acqua_residua])
    
    u1, u2 = vessel_request
    best_buoy = select_best_buoy(n, x_next, u1, u2)

    if best_buoy != -1:
        x_i = x_next[best_buoy*2:(best_buoy+1)*2]
        x_next[best_buoy*2:(best_buoy+1)*2] = vessel_considerations(x_i, cr, kc, u1, u2, max_energy, max_water)
        assigned_buoy = best_buoy + 1
    else:
        print("Non ci sono boe con risorse sufficienti per la richiesta:", vessel_request)
        assigned_buoy = -1
    
    return x_next, assigned_buoy

# Costruzione della matrice A globale
def build_global_A(n, kc):
    A = np.zeros((2*n, 2*n))
    for i in range(n):
        A[2*i:2*i+2, 2*i:2*i+2] = np.array([[1, -kc], [0, 0]])
    return A

# Simulazione
x_max = np.array([max_energy, max_water] * n)
A = build_global_A(n, kc)

# Esempio di richieste delle navi ad ogni istante temporale
vessel_requests = [
    (1.1, 1.2),
    (3.3, 2.4),
    (2.2, 4.1),
    (1.5, 1.3),
    (2.1, 2.2),
    (5.4, 4.3),
    (1.3, 1.2),
    (2.2, 3.4),
    (3.3, 2.5),
    (1.1, 1.3)
]

timesteps = len(vessel_requests)

x = x_max.copy()

# Inizializzare le liste per tenere traccia delle risorse di ogni boa
energia_boe = [[] for _ in range(n)]
acqua_boe = [[] for _ in range(n)]
assigned_times = [[] for _ in range(n)]

for k in range(timesteps):
    vessel_request = vessel_requests[k]
    x, assigned_buoy = multiple_buoys_with_vessels(n, x, cr, kc, vessel_request, max_energy, max_water)
    
    # Aggiornare le liste delle risorse per la visualizzazione
    for i in range(n):
        energia_boe[i].append(x[2*i])
        acqua_boe[i].append(x[2*i+1])
    
    print(f"Tempo {k+1}:")
    print(f" Richiesta del natante - Energia: {vessel_request[0]:.1f}, Acqua: {vessel_request[1]:.1f}")
    if assigned_buoy != -1:
        print(f" Assegnato alla boa {assigned_buoy}")
        assigned_times[assigned_buoy-1].append(k)
    else:
        print(" Nessuna boa assegnata")
    for i in range(n):
        print(f" Boa {i+1} - Energia: {x[2*i]:.1f}, Acqua: {x[2*i+1]:.1f}")

print("Stato finale delle boe:")
for i in range(n):
    print(f" Boa {i+1} - Energia: {x[2*i]:.1f}, Acqua: {x[2*i+1]:.1f}")

plt.figure(figsize=(12, 6))

for i in range(n):
    plt.subplot(2, 1, 1)
    plt.plot(energia_boe[i], label=f'Boa {i+1}')
    for t in assigned_times[i]:
        plt.plot(t, energia_boe[i][t], 'o', color='black')  # Marker per l'assegnazione del natante in nero
    plt.title('Energia di ogni boa nel tempo')
    plt.xlabel('Tempo')
    plt.ylabel('Energia')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(acqua_boe[i], label=f'Boa {i+1}')
    for t in assigned_times[i]:
        plt.plot(t, acqua_boe[i][t], 'o', color='black')  # Marker per l'assegnazione del natante in nero
    plt.title('Acqua di ogni boa nel tempo')
    plt.xlabel('Tempo')
    plt.ylabel('Acqua')
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Tempo 1:
#  Richiesta del natante - Energia: 1.1, Acqua: 1.2
#  Assegnato alla boa 1
#  Boa 1 - Energia: 8.9, Acqua: 9.8
#  Boa 2 - Energia: 10.0, Acqua: 10.0
#  Boa 3 - Energia: 10.0, Acqua: 10.0
# Tempo 2:
#  Richiesta del natante - Energia: 3.3, Acqua: 2.4
#  Assegnato alla boa 2
#  Boa 1 - Energia: 9.9, Acqua: 10.0
#  Boa 2 - Energia: 6.7, Acqua: 8.6
#  Boa 3 - Energia: 10.0, Acqua: 10.0
# Tempo 3:
#  Richiesta del natante - Energia: 2.2, Acqua: 4.1
#  Assegnato alla boa 1
#  Boa 1 - Energia: 7.8, Acqua: 6.9
#  Boa 2 - Energia: 7.7, Acqua: 9.6
#  Boa 3 - Energia: 10.0, Acqua: 10.0
# Tempo 4:
#  Richiesta del natante - Energia: 1.5, Acqua: 1.3
#  Assegnato alla boa 3
#  Boa 1 - Energia: 8.8, Acqua: 7.9
#  Boa 2 - Energia: 8.7, Acqua: 10.0
#  Boa 3 - Energia: 8.5, Acqua: 9.7
# Tempo 5:
#  Richiesta del natante - Energia: 2.1, Acqua: 2.2
#  Assegnato alla boa 2
#  Boa 1 - Energia: 9.8, Acqua: 8.9
#  Boa 2 - Energia: 7.6, Acqua: 8.8
#  Boa 3 - Energia: 9.5, Acqua: 10.0
# Tempo 6:
# ...
